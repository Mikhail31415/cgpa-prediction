# %%
from copy import deepcopy
from pathlib import Path

import pandas as pd
import numpy as np

import torch
import torch.nn as nn

from src.dataset_loader import get_np_dataset
from src.grades_dataset import TensorDatasetGpu
from src.models import GradePredictionModel

# %%
path = Path(r'C:\Python\projects\CGPAPrediction\data\final_grade_prediction_dataset')

# %%
emb_threshold = 25

data, y_data, emb_dims, one_hot_dims = get_np_dataset(emb_threshold, dataset_path=path)
y_val = y_data['val'].numpy()
y_test = y_data['test'].numpy()

# %%
inputs_description = {'Educational Program / Major': 'embedding', 'Payment Type': 'one-hot',
                      'Funding Type': 'one-hot', 'Language of Instruction': 'one-hot',
                      'Institute': 'one-hot', 'Study Mode': 'one-hot', 'Course': 'embedding',
                      'Instructor Full Name': 'embedding', 'Instructor Department': 'embedding',
                      'Student Gender': 'one-hot', 'Instructor Gender': 'one-hot', 'Rating': 'number',
                      'Midterm 1': 'number', 'Midterm 2': 'number'}

# %%
inputs_description
# Out:
# {'Educational Program / Major': ('embedding', (58, 7)),
#  'Payment Type': ('one-hot', 2),
#  'Funding Type': ('one-hot', 9),
#  'Language of Instruction': ('one-hot', 2),
#  'Institute': ('one-hot', 13),
#  'Study Mode': ('one-hot', 7),
#  'Course': ('embedding', (502, 22)),
#  'Instructor Full Name': ('embedding', (443, 21)),
#  'Instructor Department': ('embedding', (73, 8)),
#  'Student Gender': ('one-hot', 2),
#  'Instructor Gender': ('one-hot', 2),
#  'Rating': ('number',),
#  'Midterm 1': ('number',),
#  'Midterm 2': ('number',)}

# %%
{k: v for k, v in inputs_description.items() if v[0] == 'number'}
# Out:
# {'Rating': ('number',), 'Midterm 1': ('number',), 'Midterm 2': ('number',)}

# %%
for col, input_type in inputs_description.items():
    if input_type == 'embedding':
        inputs_description[col] = ('embedding', (emb_dims[col]))
    elif input_type == 'one-hot':
        inputs_description[col] = ('one-hot', one_hot_dims[col])
    else:
        inputs_description[col] = (inputs_description[col],)

other_semesters_inputs_description = inputs_description.copy()
other_semesters_inputs_description['Final Grade'] = ('number',)

# %%
loss_weights = 1 / torch.from_numpy(pd.Series(y_data['train']).value_counts().sort_index().values)
loss_weights = loss_weights / loss_weights.sum() * loss_weights.size(0)

# %%
loss_weights
# Out:
# tensor([1.8108, 0.5129, 0.6763])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("✅ Using device:", device)
# Out:
# ✅ Using device: cuda

# %%
train_dataset = TensorDatasetGpu(data['train'], y_data['train'], device)
x_val = TensorDatasetGpu.move_to_device(data['val'], device)
x_test = TensorDatasetGpu.move_to_device(data['test'], device)
loss_weights = loss_weights.to(device)

# %%
def show_device(x):
    if torch.is_tensor(x):
        print(x.device)
    elif isinstance(x, dict):
        for k, v in x.items():
            if torch.is_tensor(v):
                print(f"{k}: {v.device}")

# %%
params = {
    'lstm_hidden': 64,
    'attn_hidden': 64,
    'l1': 64,
    'l2': 32,
    'num_classes': 3,
    'dropout': 0.0,
    'num_lstm_layers': 2,
}

best_model = None
best_f1 = 0
learning_data = []

# %%
inputs_description
# Out:
# {'Educational Program / Major': ('embedding', (58, 7)),
#  'Payment Type': ('one-hot', 2),
#  'Funding Type': ('one-hot', 9),
#  'Language of Instruction': ('one-hot', 2),
#  'Institute': ('one-hot', 13),
#  'Study Mode': ('one-hot', 7),
#  'Course': ('embedding', (502, 22)),
#  'Instructor Full Name': ('embedding', (443, 21)),
#  'Instructor Department': ('embedding', (73, 8)),
#  'Student Gender': ('one-hot', 2),
#  'Instructor Gender': ('one-hot', 2),
#  'Rating': ('number',),
#  'Midterm 1': ('number',),
#  'Midterm 2': ('number',)}

# %%
from src.utils import evaluate_model

batch_size = 64

model = GradePredictionModel(inputs_description, params).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
loss_fn = nn.CrossEntropyLoss(reduction='none')

epochs_without_improvements = 0
max_epochs_without_improvements = 20
early_stop_count = 0
max_early_stop_count = 50
lr_step = 0.4

epochs = 100
for i in range(epochs):
    for x, y in train_dataset.iter_batches(batch_size):
        optimizer.zero_grad()
        preds = model(**x)
        loss = loss_fn(preds, y)
        weights = loss_weights[y]
        loss = (loss * weights).mean()

        loss.backward()
        optimizer.step()

    print(f"Epoch: {i}")
    print(f"Learning rate: {optimizer.param_groups[0]['lr']}")
    print("Train:")
    model.eval()
    with torch.no_grad():
        train_preds = model(**train_dataset.x_gpu).argmax(dim=1).cpu().numpy()
        train_true = train_dataset.y_cpu.numpy()
        evaluate_model(train_true, train_preds, learning_data)
        print("Val:")
        f1weighted = evaluate_model(y_val, model(**x_val).argmax(dim=1).cpu().numpy(), learning_data)
        if f1weighted > best_f1:
            early_stop_count = 0
            epochs_without_improvements = 0
            best_f1 = f1weighted
            best_model = deepcopy(model)
        else:
            early_stop_count += 1
            if early_stop_count == max_early_stop_count:
                break
            epochs_without_improvements += 1
            print(f"Epochs without improvements - {epochs_without_improvements}")
            if epochs_without_improvements == max_epochs_without_improvements:
                epochs_without_improvements = 0
                optimizer.param_groups[0]['lr'] *= lr_step
                print(f"Current LR - {optimizer.param_groups[0]['lr']}")
                model = deepcopy(best_model)
                model.lstm.flatten_parameters()
    model.train()
# Out:
# Epoch: 0
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.4443
#   Precision (w):  0.4908
#   Recall (w):     0.4443
#   Precision (per class):  ['0.2915', '0.5803', '0.4472']
#   Recall (per class):  ['0.3905', '0.2318', '0.7446']
#   F1 (macro):     0.4080
#   F1 (weighted):  0.4162
#
# Confusion Matrix:
#      0     1     2
# 0  562   301   576
# 1  933  1178  2970
# 2  433   551  2869
# Val:
#   Metrics:
#   Accuracy:       0.4332
#   Precision (w):  0.4809
#   Recall (w):     0.4332
#   Precision (per class):  ['0.3134', '0.5754', '0.4207']
#   Recall (per class):  ['0.3808', '0.2446', '0.7244']
#   F1 (macro):     0.4065
#   F1 (weighted):  0.4094
#
# Confusion Matrix:
#      0    1    2
# 0  131   79  134
# 1  193  271  644
# 2   94  121  565
# Epoch: 1
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.4520
#   Precision (w):  0.5338
#   Recall (w):     0.4520
#   Precision (per class):  ['0.2955', '0.6196', '0.5097']
#   Recall (per class):  ['0.6852', '0.1295', '0.7903']
#   F1 (macro):     0.4156
#   F1 (weighted):  0.3924
#
# Confusion Matrix:
#       0    1     2
# 0   986  130   323
# 1  1817  658  2606
# 2   534  274  3045
# Val:
#   Metrics:
#   Accuracy:       0.4547
#   Precision (w):  0.5120
#   Recall (w):     0.4547
#   Precision (per class):  ['0.3427', '0.5788', '0.4920']
#   Recall (per class):  ['0.7122', '0.1426', '0.7846']
#   F1 (macro):     0.4321
#   F1 (weighted):  0.3962
#
# Confusion Matrix:
#      0    1    2
# 0  245   36   63
# 1  381  158  569
# 2   89   79  612
# Epochs without improvements - 1
# Epoch: 2
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.5308
#   Precision (w):  0.5689
#   Recall (w):     0.5308
#   Precision (per class):  ['0.3837', '0.6362', '0.5493']
#   Recall (per class):  ['0.6525', '0.3070', '0.7804']
#   F1 (macro):     0.5141
#   F1 (weighted):  0.5094
#
# Confusion Matrix:
#       0     1     2
# 0   939   309   191
# 1  1245  1560  2276
# 2   263   583  3007
# Val:
#   Metrics:
#   Accuracy:       0.5040
#   Precision (w):  0.5302
#   Recall (w):     0.5040
#   Precision (per class):  ['0.4087', '0.5802', '0.5127']
#   Recall (per class):  ['0.6250', '0.2744', '0.7769']
#   F1 (macro):     0.4948
#   F1 (weighted):  0.4770
#
# Confusion Matrix:
#      0    1    2
# 0  215   88   41
# 1  269  304  535
# 2   42  132  606
# Epoch: 3
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.5725
#   Precision (w):  0.6019
#   Recall (w):     0.5725
#   Precision (per class):  ['0.4179', '0.6582', '0.5963']
#   Recall (per class):  ['0.7074', '0.3934', '0.7584']
#   F1 (macro):     0.5619
#   F1 (weighted):  0.5621
#
# Confusion Matrix:
#       0     1     2
# 0  1018   307   114
# 1  1218  1999  1864
# 2   200   731  2922
# Val:
#   Metrics:
#   Accuracy:       0.5336
#   Precision (w):  0.5619
#   Recall (w):     0.5336
#   Precision (per class):  ['0.4026', '0.6201', '0.5495']
#   Recall (per class):  ['0.6250', '0.3403', '0.7679']
#   F1 (macro):     0.5233
#   F1 (weighted):  0.5175
#
# Confusion Matrix:
#      0    1    2
# 0  215   95   34
# 1  274  377  457
# 2   45  136  599
# Epoch: 4
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.6065
#   Precision (w):  0.6298
#   Recall (w):     0.6065
#   Precision (per class):  ['0.4509', '0.6770', '0.6344']
#   Recall (per class):  ['0.7429', '0.4546', '0.7558']
#   F1 (macro):     0.5983
#   F1 (weighted):  0.6005
#
# Confusion Matrix:
#       0     1     2
# 0  1069   309    61
# 1  1154  2310  1617
# 2   148   793  2912
# Val:
#   Metrics:
#   Accuracy:       0.5659
#   Precision (w):  0.5869
#   Recall (w):     0.5659
#   Precision (per class):  ['0.4526', '0.6384', '0.5730']
#   Recall (per class):  ['0.6802', '0.4079', '0.7397']
#   F1 (macro):     0.5624
#   F1 (weighted):  0.5566
#
# Confusion Matrix:
#      0    1    2
# 0  234   84   26
# 1  252  452  404
# 2   31  172  577
# Epoch: 5
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.6388
#   Precision (w):  0.6647
#   Recall (w):     0.6388
#   Precision (per class):  ['0.4640', '0.6876', '0.7094']
#   Recall (per class):  ['0.8499', '0.5324', '0.7002']
#   F1 (macro):     0.6351
#   F1 (weighted):  0.6390
#
# Confusion Matrix:
#       0     1     2
# 0  1223   201    15
# 1  1286  2705  1090
# 2   127  1028  2698
# Val:
#   Metrics:
#   Accuracy:       0.5851
#   Precision (w):  0.6043
#   Recall (w):     0.5851
#   Precision (per class):  ['0.4598', '0.6403', '0.6169']
#   Recall (per class):  ['0.7645', '0.4675', '0.6731']
#   F1 (macro):     0.5861
#   F1 (weighted):  0.5818
#
# Confusion Matrix:
#      0    1    2
# 0  263   61   20
# 1  284  518  306
# 2   25  230  525
# Epoch: 6
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.6858
#   Precision (w):  0.6977
#   Recall (w):     0.6858
#   Precision (per class):  ['0.5577', '0.7260', '0.7126']
#   Recall (per class):  ['0.8325', '0.5871', '0.7612']
#   F1 (macro):     0.6844
#   F1 (weighted):  0.6841
#
# Confusion Matrix:
#       0     1     2
# 0  1198   236     5
# 1   920  2983  1178
# 2    30   890  2933
# Val:
#   Metrics:
#   Accuracy:       0.6340
#   Precision (w):  0.6408
#   Recall (w):     0.6340
#   Precision (per class):  ['0.5581', '0.6719', '0.6332']
#   Recall (per class):  ['0.7122', '0.5433', '0.7282']
#   F1 (macro):     0.6347
#   F1 (weighted):  0.6314
#
# Confusion Matrix:
#      0    1    2
# 0  245   88   11
# 1  188  602  318
# 2    6  206  568
# Epoch: 7
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.7137
#   Precision (w):  0.7272
#   Recall (w):     0.7137
#   Precision (per class):  ['0.5780', '0.7656', '0.7324']
#   Recall (per class):  ['0.8527', '0.6062', '0.8035']
#   F1 (macro):     0.7106
#   F1 (weighted):  0.7117
#
# Confusion Matrix:
#       0     1     2
# 0  1227   205     7
# 1   877  3080  1124
# 2    19   738  3096
# Val:
#   Metrics:
#   Accuracy:       0.6537
#   Precision (w):  0.6630
#   Recall (w):     0.6537
#   Precision (per class):  ['0.5603', '0.7005', '0.6550']
#   Recall (per class):  ['0.7297', '0.5487', '0.7692']
#   F1 (macro):     0.6523
#   F1 (weighted):  0.6504
#
# Confusion Matrix:
#      0    1    2
# 0  251   83   10
# 1  194  608  306
# 2    3  177  600
# Epoch: 8
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.7440
#   Precision (w):  0.7558
#   Recall (w):     0.7440
#   Precision (per class):  ['0.6196', '0.7972', '0.7521']
#   Recall (per class):  ['0.8749', '0.6428', '0.8284']
#   F1 (macro):     0.7419
#   F1 (weighted):  0.7421
#
# Confusion Matrix:
#       0     1     2
# 0  1259   179     1
# 1   764  3266  1051
# 2     9   652  3192
# Val:
#   Metrics:
#   Accuracy:       0.6868
#   Precision (w):  0.6964
#   Recall (w):     0.6868
#   Precision (per class):  ['0.5959', '0.7374', '0.6824']
#   Recall (per class):  ['0.7674', '0.5830', '0.7987']
#   F1 (macro):     0.6860
#   F1 (weighted):  0.6839
#
# Confusion Matrix:
#      0    1    2
# 0  264   75    5
# 1  177  646  285
# 2    2  155  623
# Epoch: 9
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.7478
#   Precision (w):  0.7678
#   Recall (w):     0.7478
#   Precision (per class):  ['0.6683', '0.8410', '0.7083']
#   Recall (per class):  ['0.8429', '0.6017', '0.9050']
#   F1 (macro):     0.7472
#   F1 (weighted):  0.7422
#
# Confusion Matrix:
#       0     1     2
# 0  1213   220     6
# 1   594  3057  1430
# 2     8   358  3487
# Val:
#   Metrics:
#   Accuracy:       0.6891
#   Precision (w):  0.7127
#   Recall (w):     0.6891
#   Precision (per class):  ['0.6443', '0.7843', '0.6414']
#   Recall (per class):  ['0.7529', '0.5217', '0.8987']
#   F1 (macro):     0.6898
#   F1 (weighted):  0.6796
#
# Confusion Matrix:
#      0    1    2
# 0  259   81    4
# 1  142  578  388
# 2    1   78  701
# Epochs without improvements - 1
# Epoch: 10
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.7789
#   Precision (w):  0.7925
#   Recall (w):     0.7789
#   Precision (per class):  ['0.6756', '0.8523', '0.7574']
#   Recall (per class):  ['0.8784', '0.6654', '0.8915']
#   F1 (macro):     0.7767
#   F1 (weighted):  0.7762
#
# Confusion Matrix:
#       0     1     2
# 0  1264   173     2
# 1   602  3381  1098
# 2     5   413  3435
# Val:
#   Metrics:
#   Accuracy:       0.7227
#   Precision (w):  0.7324
#   Recall (w):     0.7227
#   Precision (per class):  ['0.6502', '0.7806', '0.7003']
#   Recall (per class):  ['0.7674', '0.6164', '0.8538']
#   F1 (macro):     0.7208
#   F1 (weighted):  0.7194
#
# Confusion Matrix:
#      0    1    2
# 0  264   79    1
# 1  141  683  284
# 2    1  113  666
# Epoch: 11
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.7752
#   Precision (w):  0.7912
#   Recall (w):     0.7752
#   Precision (per class):  ['0.6054', '0.8097', '0.8362']
#   Recall (per class):  ['0.9382', '0.7091', '0.8015']
#   F1 (macro):     0.7701
#   F1 (weighted):  0.7764
#
# Confusion Matrix:
#       0     1     2
# 0  1350    89     0
# 1   873  3603   605
# 2     7   758  3088
# Val:
#   Metrics:
#   Accuracy:       0.7316
#   Precision (w):  0.7412
#   Recall (w):     0.7316
#   Precision (per class):  ['0.6071', '0.7629', '0.7695']
#   Recall (per class):  ['0.8488', '0.6679', '0.7705']
#   F1 (macro):     0.7300
#   F1 (weighted):  0.7318
#
# Confusion Matrix:
#      0    1    2
# 0  292   52    0
# 1  188  740  180
# 2    1  178  601
# Epoch: 12
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8077
#   Precision (w):  0.8152
#   Recall (w):     0.8077
#   Precision (per class):  ['0.7039', '0.8556', '0.8035']
#   Recall (per class):  ['0.8972', '0.7310', '0.8754']
#   F1 (macro):     0.8051
#   F1 (weighted):  0.8068
#
# Confusion Matrix:
#       0     1     2
# 0  1291   148     0
# 1   542  3714   825
# 2     1   479  3373
# Val:
#   Metrics:
#   Accuracy:       0.7639
#   Precision (w):  0.7694
#   Recall (w):     0.7639
#   Precision (per class):  ['0.6888', '0.8076', '0.7506']
#   Recall (per class):  ['0.7849', '0.6895', '0.8603']
#   F1 (macro):     0.7598
#   F1 (weighted):  0.7625
#
# Confusion Matrix:
#      0    1    2
# 0  270   74    0
# 1  121  764  223
# 2    1  108  671
# Epoch: 13
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8083
#   Precision (w):  0.8213
#   Recall (w):     0.8083
#   Precision (per class):  ['0.6821', '0.8762', '0.8010']
#   Recall (per class):  ['0.9291', '0.7091', '0.8941']
#   F1 (macro):     0.8052
#   F1 (weighted):  0.8070
#
# Confusion Matrix:
#       0     1     2
# 0  1337   102     0
# 1   622  3603   856
# 2     1   407  3445
# Val:
#   Metrics:
#   Accuracy:       0.7527
#   Precision (w):  0.7644
#   Recall (w):     0.7527
#   Precision (per class):  ['0.6566', '0.8181', '0.7357']
#   Recall (per class):  ['0.8227', '0.6453', '0.8744']
#   F1 (macro):     0.7503
#   F1 (weighted):  0.7500
#
# Confusion Matrix:
#      0    1    2
# 0  283   61    0
# 1  148  715  245
# 2    0   98  682
# Epochs without improvements - 1
# Epoch: 14
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8299
#   Precision (w):  0.8353
#   Recall (w):     0.8299
#   Precision (per class):  ['0.7172', '0.8602', '0.8467']
#   Recall (per class):  ['0.9076', '0.7798', '0.8671']
#   F1 (macro):     0.8253
#   F1 (weighted):  0.8301
#
# Confusion Matrix:
#       0     1     2
# 0  1306   133     0
# 1   514  3962   605
# 2     1   511  3341
# Val:
#   Metrics:
#   Accuracy:       0.7800
#   Precision (w):  0.7820
#   Recall (w):     0.7800
#   Precision (per class):  ['0.7249', '0.8039', '0.7759']
#   Recall (per class):  ['0.7965', '0.7365', '0.8346']
#   F1 (macro):     0.7773
#   F1 (weighted):  0.7796
#
# Confusion Matrix:
#      0    1    2
# 0  274   70    0
# 1  104  816  188
# 2    0  129  651
# Epoch: 15
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.7955
#   Precision (w):  0.8202
#   Recall (w):     0.7955
#   Precision (per class):  ['0.5858', '0.8281', '0.8975']
#   Recall (per class):  ['0.9722', '0.7355', '0.8087']
#   F1 (macro):     0.7870
#   F1 (weighted):  0.7990
#
# Confusion Matrix:
#       0     1     2
# 0  1399    40     0
# 1   988  3737   356
# 2     1   736  3116
# Val:
#   Metrics:
#   Accuracy:       0.7693
#   Precision (w):  0.7827
#   Recall (w):     0.7693
#   Precision (per class):  ['0.6225', '0.8000', '0.8288']
#   Recall (per class):  ['0.9157', '0.7148', '0.7821']
#   F1 (macro):     0.7670
#   F1 (weighted):  0.7703
#
# Confusion Matrix:
#      0    1    2
# 0  315   29    0
# 1  190  792  126
# 2    1  169  610
# Epochs without improvements - 1
# Epoch: 16
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8456
#   Precision (w):  0.8526
#   Recall (w):     0.8456
#   Precision (per class):  ['0.7573', '0.8989', '0.8271']
#   Recall (per class):  ['0.9173', '0.7715', '0.9164']
#   F1 (macro):     0.8432
#   F1 (weighted):  0.8448
#
# Confusion Matrix:
#       0     1     2
# 0  1320   119     0
# 1   423  3920   738
# 2     0   322  3531
# Val:
#   Metrics:
#   Accuracy:       0.7899
#   Precision (w):  0.7974
#   Recall (w):     0.7899
#   Precision (per class):  ['0.7421', '0.8447', '0.7546']
#   Recall (per class):  ['0.8198', '0.7067', '0.8949']
#   F1 (macro):     0.7891
#   F1 (weighted):  0.7882
#
# Confusion Matrix:
#      0    1    2
# 0  282   62    0
# 1   98  783  227
# 2    0   82  698
# Epoch: 17
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8460
#   Precision (w):  0.8519
#   Recall (w):     0.8460
#   Precision (per class):  ['0.7284', '0.8761', '0.8662']
#   Recall (per class):  ['0.9354', '0.7987', '0.8752']
#   F1 (macro):     0.8417
#   F1 (weighted):  0.8463
#
# Confusion Matrix:
#       0     1     2
# 0  1346    93     0
# 1   502  4058   521
# 2     0   481  3372
# Val:
#   Metrics:
#   Accuracy:       0.8078
#   Precision (w):  0.8121
#   Recall (w):     0.8078
#   Precision (per class):  ['0.7255', '0.8433', '0.8060']
#   Recall (per class):  ['0.8605', '0.7527', '0.8628']
#   F1 (macro):     0.8054
#   F1 (weighted):  0.8074
#
# Confusion Matrix:
#      0    1    2
# 0  296   48    0
# 1  112  834  162
# 2    0  107  673
# Epoch: 18
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8520
#   Precision (w):  0.8605
#   Recall (w):     0.8520
#   Precision (per class):  ['0.7318', '0.9042', '0.8509']
#   Recall (per class):  ['0.9500', '0.7806', '0.9097']
#   F1 (macro):     0.8480
#   F1 (weighted):  0.8517
#
# Confusion Matrix:
#       0     1     2
# 0  1367    72     0
# 1   501  3966   614
# 2     0   348  3505
# Val:
#   Metrics:
#   Accuracy:       0.8087
#   Precision (w):  0.8166
#   Recall (w):     0.8087
#   Precision (per class):  ['0.7481', '0.8665', '0.7758']
#   Recall (per class):  ['0.8547', '0.7265', '0.9051']
#   F1 (macro):     0.8079
#   F1 (weighted):  0.8073
#
# Confusion Matrix:
#      0    1    2
# 0  294   50    0
# 1   99  805  204
# 2    0   74  706
# Epochs without improvements - 1
# Epoch: 19
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8485
#   Precision (w):  0.8613
#   Recall (w):     0.8485
#   Precision (per class):  ['0.6779', '0.8798', '0.9054']
#   Recall (per class):  ['0.9785', '0.7998', '0.8640']
#   F1 (macro):     0.8410
#   F1 (weighted):  0.8500
#
# Confusion Matrix:
#       0     1     2
# 0  1408    31     0
# 1   669  4064   348
# 2     0   524  3329
# Val:
#   Metrics:
#   Accuracy:       0.8127
#   Precision (w):  0.8199
#   Recall (w):     0.8127
#   Precision (per class):  ['0.6904', '0.8423', '0.8452']
#   Recall (per class):  ['0.9012', '0.7662', '0.8397']
#   F1 (macro):     0.8089
#   F1 (weighted):  0.8133
#
# Confusion Matrix:
#      0    1    2
# 0  310   34    0
# 1  139  849  120
# 2    0  125  655
# Epoch: 20
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8604
#   Precision (w):  0.8734
#   Recall (w):     0.8604
#   Precision (per class):  ['0.8316', '0.9421', '0.7983']
#   Recall (per class):  ['0.9263', '0.7619', '0.9657']
#   F1 (macro):     0.8643
#   F1 (weighted):  0.8589
#
# Confusion Matrix:
#       0     1     2
# 0  1333   106     0
# 1   270  3871   940
# 2     0   132  3721
# Val:
#   Metrics:
#   Accuracy:       0.8033
#   Precision (w):  0.8197
#   Recall (w):     0.8033
#   Precision (per class):  ['0.7983', '0.8867', '0.7340']
#   Recall (per class):  ['0.8169', '0.6922', '0.9551']
#   F1 (macro):     0.8050
#   F1 (weighted):  0.8005
#
# Confusion Matrix:
#      0    1    2
# 0  281   63    0
# 1   71  767  270
# 2    0   35  745
# Epochs without improvements - 1
# Epoch: 21
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8761
#   Precision (w):  0.8826
#   Recall (w):     0.8761
#   Precision (per class):  ['0.8215', '0.9323', '0.8399']
#   Recall (per class):  ['0.9305', '0.8056', '0.9489']
#   F1 (macro):     0.8760
#   F1 (weighted):  0.8754
#
# Confusion Matrix:
#       0     1     2
# 0  1339   100     0
# 1   291  4093   697
# 2     0   197  3656
# Val:
#   Metrics:
#   Accuracy:       0.8280
#   Precision (w):  0.8367
#   Recall (w):     0.8280
#   Precision (per class):  ['0.8006', '0.8892', '0.7780']
#   Recall (per class):  ['0.8285', '0.7464', '0.9436']
#   F1 (macro):     0.8262
#   F1 (weighted):  0.8264
#
# Confusion Matrix:
#      0    1    2
# 0  285   59    0
# 1   71  827  210
# 2    0   44  736
# Epoch: 22
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8666
#   Precision (w):  0.8755
#   Recall (w):     0.8666
#   Precision (per class):  ['0.7225', '0.8806', '0.9261']
#   Recall (per class):  ['0.9771', '0.8418', '0.8580']
#   F1 (macro):     0.8607
#   F1 (weighted):  0.8677
#
# Confusion Matrix:
#       0     1     2
# 0  1406    33     0
# 1   540  4277   264
# 2     0   547  3306
# Val:
#   Metrics:
#   Accuracy:       0.8342
#   Precision (w):  0.8391
#   Recall (w):     0.8342
#   Precision (per class):  ['0.7254', '0.8494', '0.8747']
#   Recall (per class):  ['0.8983', '0.8096', '0.8410']
#   F1 (macro):     0.8297
#   F1 (weighted):  0.8349
#
# Confusion Matrix:
#      0    1    2
# 0  309   35    0
# 1  117  897   94
# 2    0  124  656
# Epoch: 23
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8859
#   Precision (w):  0.8904
#   Recall (w):     0.8859
#   Precision (per class):  ['0.7822', '0.9173', '0.8952']
#   Recall (per class):  ['0.9632', '0.8429', '0.9136']
#   F1 (macro):     0.8820
#   F1 (weighted):  0.8860
#
# Confusion Matrix:
#       0     1     2
# 0  1386    53     0
# 1   386  4283   412
# 2     0   333  3520
# Val:
#   Metrics:
#   Accuracy:       0.8396
#   Precision (w):  0.8428
#   Recall (w):     0.8396
#   Precision (per class):  ['0.7686', '0.8735', '0.8319']
#   Recall (per class):  ['0.8692', '0.7915', '0.8949']
#   F1 (macro):     0.8362
#   F1 (weighted):  0.8393
#
# Confusion Matrix:
#      0    1    2
# 0  299   45    0
# 1   90  877  141
# 2    0   82  698
# Epoch: 24
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8775
#   Precision (w):  0.8856
#   Recall (w):     0.8775
#   Precision (per class):  ['0.7360', '0.9131', '0.9053']
#   Recall (per class):  ['0.9805', '0.8288', '0.9032']
#   F1 (macro):     0.8713
#   F1 (weighted):  0.8781
#
# Confusion Matrix:
#       0     1     2
# 0  1411    28     0
# 1   506  4211   364
# 2     0   373  3480
# Val:
#   Metrics:
#   Accuracy:       0.8387
#   Precision (w):  0.8442
#   Recall (w):     0.8387
#   Precision (per class):  ['0.7398', '0.8809', '0.8383']
#   Recall (per class):  ['0.8924', '0.7807', '0.8974']
#   F1 (macro):     0.8345
#   F1 (weighted):  0.8385
#
# Confusion Matrix:
#      0    1    2
# 0  307   37    0
# 1  108  865  135
# 2    0   80  700
# Epochs without improvements - 1
# Epoch: 25
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8804
#   Precision (w):  0.8888
#   Recall (w):     0.8804
#   Precision (per class):  ['0.8664', '0.9442', '0.8242']
#   Recall (per class):  ['0.9104', '0.8032', '0.9709']
#   F1 (macro):     0.8825
#   F1 (weighted):  0.8795
#
# Confusion Matrix:
#       0     1     2
# 0  1310   129     0
# 1   202  4081   798
# 2     0   112  3741
# Val:
#   Metrics:
#   Accuracy:       0.8203
#   Precision (w):  0.8329
#   Recall (w):     0.8203
#   Precision (per class):  ['0.8502', '0.8863', '0.7495']
#   Recall (per class):  ['0.8081', '0.7319', '0.9513']
#   F1 (macro):     0.8229
#   F1 (weighted):  0.8187
#
# Confusion Matrix:
#      0    1    2
# 0  278   66    0
# 1   49  811  248
# 2    0   38  742
# Epochs without improvements - 2
# Epoch: 26
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8902
#   Precision (w):  0.8969
#   Recall (w):     0.8902
#   Precision (per class):  ['0.7648', '0.9302', '0.9023']
#   Recall (per class):  ['0.9785', '0.8388', '0.9250']
#   F1 (macro):     0.8847
#   F1 (weighted):  0.8905
#
# Confusion Matrix:
#       0     1     2
# 0  1408    31     0
# 1   433  4262   386
# 2     0   289  3564
# Val:
#   Metrics:
#   Accuracy:       0.8490
#   Precision (w):  0.8543
#   Recall (w):     0.8490
#   Precision (per class):  ['0.7599', '0.8938', '0.8398']
#   Recall (per class):  ['0.8924', '0.7897', '0.9141']
#   F1 (macro):     0.8449
#   F1 (weighted):  0.8487
#
# Confusion Matrix:
#      0    1    2
# 0  307   37    0
# 1   97  875  136
# 2    0   67  713
# Epoch: 27
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8905
#   Precision (w):  0.8965
#   Recall (w):     0.8905
#   Precision (per class):  ['0.7637', '0.9166', '0.9198']
#   Recall (per class):  ['0.9812', '0.8542', '0.9045']
#   F1 (macro):     0.8851
#   F1 (weighted):  0.8911
#
# Confusion Matrix:
#       0     1     2
# 0  1412    27     0
# 1   437  4340   304
# 2     0   368  3485
# Val:
#   Metrics:
#   Accuracy:       0.8504
#   Precision (w):  0.8537
#   Recall (w):     0.8504
#   Precision (per class):  ['0.7637', '0.8802', '0.8559']
#   Recall (per class):  ['0.8924', '0.8087', '0.8910']
#   F1 (macro):     0.8464
#   F1 (weighted):  0.8504
#
# Confusion Matrix:
#      0    1    2
# 0  307   37    0
# 1   95  896  117
# 2    0   85  695
# Epoch: 28
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9003
#   Precision (w):  0.9059
#   Recall (w):     0.9003
#   Precision (per class):  ['0.8386', '0.9532', '0.8688']
#   Recall (per class):  ['0.9604', '0.8376', '0.9606']
#   F1 (macro):     0.8998
#   F1 (weighted):  0.8999
#
# Confusion Matrix:
#       0     1     2
# 0  1382    57     0
# 1   266  4256   559
# 2     0   152  3701
# Val:
#   Metrics:
#   Accuracy:       0.8360
#   Precision (w):  0.8429
#   Recall (w):     0.8360
#   Precision (per class):  ['0.8134', '0.8897', '0.7894']
#   Recall (per class):  ['0.8488', '0.7644', '0.9321']
#   F1 (macro):     0.8359
#   F1 (weighted):  0.8350
#
# Confusion Matrix:
#      0    1    2
# 0  292   52    0
# 1   67  847  194
# 2    0   53  727
# Epochs without improvements - 1
# Epoch: 29
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8961
#   Precision (w):  0.9022
#   Recall (w):     0.8961
#   Precision (per class):  ['0.8516', '0.9519', '0.8555']
#   Recall (per class):  ['0.9534', '0.8298', '0.9621']
#   F1 (macro):     0.8973
#   F1 (weighted):  0.8955
#
# Confusion Matrix:
#       0     1     2
# 0  1372    67     0
# 1   239  4216   626
# 2     0   146  3707
# Val:
#   Metrics:
#   Accuracy:       0.8418
#   Precision (w):  0.8488
#   Recall (w):     0.8418
#   Precision (per class):  ['0.8257', '0.8953', '0.7929']
#   Recall (per class):  ['0.8401', '0.7717', '0.9423']
#   F1 (macro):     0.8410
#   F1 (weighted):  0.8408
#
# Confusion Matrix:
#      0    1    2
# 0  289   55    0
# 1   61  855  192
# 2    0   45  735
# Epochs without improvements - 2
# Epoch: 30
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.8966
#   Precision (w):  0.9035
#   Recall (w):     0.8966
#   Precision (per class):  ['0.8899', '0.9540', '0.8419']
#   Recall (per class):  ['0.9270', '0.8288', '0.9746']
#   F1 (macro):     0.8995
#   F1 (weighted):  0.8960
#
# Confusion Matrix:
#       0     1     2
# 0  1334   105     0
# 1   165  4211   705
# 2     0    98  3755
# Val:
#   Metrics:
#   Accuracy:       0.8297
#   Precision (w):  0.8411
#   Recall (w):     0.8297
#   Precision (per class):  ['0.8598', '0.8914', '0.7615']
#   Recall (per class):  ['0.8023', '0.7482', '0.9577']
#   F1 (macro):     0.8307
#   F1 (weighted):  0.8283
#
# Confusion Matrix:
#      0    1    2
# 0  276   68    0
# 1   45  829  234
# 2    0   33  747
# Epochs without improvements - 3
# Epoch: 31
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9033
#   Precision (w):  0.9089
#   Recall (w):     0.9033
#   Precision (per class):  ['0.8458', '0.9564', '0.8698']
#   Recall (per class):  ['0.9604', '0.8410', '0.9642']
#   F1 (macro):     0.9030
#   F1 (weighted):  0.9029
#
# Confusion Matrix:
#       0     1     2
# 0  1382    57     0
# 1   252  4273   556
# 2     0   138  3715
# Val:
#   Metrics:
#   Accuracy:       0.8427
#   Precision (w):  0.8497
#   Recall (w):     0.8427
#   Precision (per class):  ['0.8192', '0.8972', '0.7957']
#   Recall (per class):  ['0.8430', '0.7717', '0.9436']
#   F1 (macro):     0.8413
#   F1 (weighted):  0.8416
#
# Confusion Matrix:
#      0    1    2
# 0  290   54    0
# 1   64  855  189
# 2    0   44  736
# Epochs without improvements - 4
# Epoch: 32
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9067
#   Precision (w):  0.9112
#   Recall (w):     0.9067
#   Precision (per class):  ['0.8275', '0.9509', '0.8902']
#   Recall (per class):  ['0.9701', '0.8536', '0.9530']
#   F1 (macro):     0.9044
#   F1 (weighted):  0.9065
#
# Confusion Matrix:
#       0     1     2
# 0  1396    43     0
# 1   291  4337   453
# 2     0   181  3672
# Val:
#   Metrics:
#   Accuracy:       0.8436
#   Precision (w):  0.8487
#   Recall (w):     0.8436
#   Precision (per class):  ['0.8000', '0.8908', '0.8103']
#   Recall (per class):  ['0.8605', '0.7807', '0.9256']
#   F1 (macro):     0.8418
#   F1 (weighted):  0.8429
#
# Confusion Matrix:
#      0    1    2
# 0  296   48    0
# 1   74  865  169
# 2    0   58  722
# Epochs without improvements - 5
# Epoch: 33
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9116
#   Precision (w):  0.9167
#   Recall (w):     0.9116
#   Precision (per class):  ['0.8205', '0.9572', '0.8992']
#   Recall (per class):  ['0.9812', '0.8579', '0.9564']
#   F1 (macro):     0.9085
#   F1 (weighted):  0.9115
#
# Confusion Matrix:
#       0     1     2
# 0  1412    27     0
# 1   309  4359   413
# 2     0   168  3685
# Val:
#   Metrics:
#   Accuracy:       0.8517
#   Precision (w):  0.8563
#   Recall (w):     0.8517
#   Precision (per class):  ['0.7937', '0.8968', '0.8264']
#   Recall (per class):  ['0.8837', '0.7924', '0.9218']
#   F1 (macro):     0.8497
#   F1 (weighted):  0.8511
#
# Confusion Matrix:
#      0    1    2
# 0  304   40    0
# 1   79  878  151
# 2    0   61  719
# Epoch: 34
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9103
#   Precision (w):  0.9150
#   Recall (w):     0.9103
#   Precision (per class):  ['0.8609', '0.9591', '0.8771']
#   Recall (per class):  ['0.9590', '0.8534', '0.9673']
#   F1 (macro):     0.9102
#   F1 (weighted):  0.9100
#
# Confusion Matrix:
#       0     1     2
# 0  1380    59     0
# 1   223  4336   522
# 2     0   126  3727
# Val:
#   Metrics:
#   Accuracy:       0.8544
#   Precision (w):  0.8612
#   Recall (w):     0.8544
#   Precision (per class):  ['0.8287', '0.9091', '0.8074']
#   Recall (per class):  ['0.8576', '0.7852', '0.9513']
#   F1 (macro):     0.8530
#   F1 (weighted):  0.8534
#
# Confusion Matrix:
#      0    1    2
# 0  295   49    0
# 1   61  870  177
# 2    0   38  742
# Epoch: 35
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9117
#   Precision (w):  0.9168
#   Recall (w):     0.9117
#   Precision (per class):  ['0.7957', '0.9460', '0.9235']
#   Recall (per class):  ['0.9854', '0.8693', '0.9400']
#   F1 (macro):     0.9061
#   F1 (weighted):  0.9120
#
# Confusion Matrix:
#       0     1     2
# 0  1418    21     0
# 1   364  4417   300
# 2     0   231  3622
# Val:
#   Metrics:
#   Accuracy:       0.8629
#   Precision (w):  0.8663
#   Recall (w):     0.8629
#   Precision (per class):  ['0.7766', '0.8962', '0.8632']
#   Recall (per class):  ['0.8895', '0.8186', '0.9141']
#   F1 (macro):     0.8576
#   F1 (weighted):  0.8629
#
# Confusion Matrix:
#      0    1    2
# 0  306   38    0
# 1   88  907  113
# 2    0   67  713
# Epoch: 36
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9142
#   Precision (w):  0.9183
#   Recall (w):     0.9142
#   Precision (per class):  ['0.8189', '0.9500', '0.9137']
#   Recall (per class):  ['0.9833', '0.8707', '0.9458']
#   F1 (macro):     0.9106
#   F1 (weighted):  0.9143
#
# Confusion Matrix:
#       0     1     2
# 0  1415    24     0
# 1   313  4424   344
# 2     0   209  3644
# Val:
#   Metrics:
#   Accuracy:       0.8522
#   Precision (w):  0.8561
#   Recall (w):     0.8522
#   Precision (per class):  ['0.7878', '0.8937', '0.8328']
#   Recall (per class):  ['0.8634', '0.7969', '0.9256']
#   F1 (macro):     0.8477
#   F1 (weighted):  0.8516
#
# Confusion Matrix:
#      0    1    2
# 0  297   47    0
# 1   80  883  145
# 2    0   58  722
# Epochs without improvements - 1
# Epoch: 37
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9277
#   Precision (w):  0.9288
#   Recall (w):     0.9277
#   Precision (per class):  ['0.8828', '0.9483', '0.9204']
#   Recall (per class):  ['0.9632', '0.9016', '0.9489']
#   F1 (macro):     0.9267
#   F1 (weighted):  0.9277
#
# Confusion Matrix:
#       0     1     2
# 0  1386    53     0
# 1   184  4581   316
# 2     0   197  3656
# Val:
#   Metrics:
#   Accuracy:       0.8656
#   Precision (w):  0.8673
#   Recall (w):     0.8656
#   Precision (per class):  ['0.8473', '0.8915', '0.8418']
#   Recall (per class):  ['0.8227', '0.8303', '0.9346']
#   F1 (macro):     0.8601
#   F1 (weighted):  0.8650
#
# Confusion Matrix:
#      0    1    2
# 0  283   61    0
# 1   51  920  137
# 2    0   51  729
# Epoch: 38
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9215
#   Precision (w):  0.9251
#   Recall (w):     0.9215
#   Precision (per class):  ['0.8203', '0.9459', '0.9367']
#   Recall (per class):  ['0.9868', '0.8908', '0.9377']
#   F1 (macro):     0.9169
#   F1 (weighted):  0.9218
#
# Confusion Matrix:
#       0     1     2
# 0  1420    19     0
# 1   311  4526   244
# 2     0   240  3613
# Val:
#   Metrics:
#   Accuracy:       0.8674
#   Precision (w):  0.8694
#   Recall (w):     0.8674
#   Precision (per class):  ['0.7917', '0.8911', '0.8728']
#   Recall (per class):  ['0.8837', '0.8348', '0.9064']
#   F1 (macro):     0.8622
#   F1 (weighted):  0.8674
#
# Confusion Matrix:
#      0    1    2
# 0  304   40    0
# 1   80  925  103
# 2    0   73  707
# Epoch: 39
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9272
#   Precision (w):  0.9280
#   Recall (w):     0.9272
#   Precision (per class):  ['0.8829', '0.9261', '0.9474']
#   Recall (per class):  ['0.9639', '0.9252', '0.9162']
#   F1 (macro):     0.9263
#   F1 (weighted):  0.9273
#
# Confusion Matrix:
#       0     1     2
# 0  1387    52     0
# 1   184  4701   196
# 2     0   323  3530
# Val:
#   Metrics:
#   Accuracy:       0.8660
#   Precision (w):  0.8660
#   Recall (w):     0.8660
#   Precision (per class):  ['0.8392', '0.8667', '0.8767']
#   Recall (per class):  ['0.8343', '0.8628', '0.8846']
#   F1 (macro):     0.8607
#   F1 (weighted):  0.8660
#
# Confusion Matrix:
#      0    1    2
# 0  287   57    0
# 1   55  956   97
# 2    0   90  690
# Epochs without improvements - 1
# Epoch: 40
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9228
#   Precision (w):  0.9246
#   Recall (w):     0.9228
#   Precision (per class):  ['0.8508', '0.9302', '0.9447']
#   Recall (per class):  ['0.9785', '0.9106', '0.9180']
#   F1 (macro):     0.9205
#   F1 (weighted):  0.9229
#
# Confusion Matrix:
#       0     1     2
# 0  1408    31     0
# 1   247  4627   207
# 2     0   316  3537
# Val:
#   Metrics:
#   Accuracy:       0.8692
#   Precision (w):  0.8700
#   Recall (w):     0.8692
#   Precision (per class):  ['0.8038', '0.8820', '0.8821']
#   Recall (per class):  ['0.8576', '0.8502', '0.9013']
#   F1 (macro):     0.8624
#   F1 (weighted):  0.8693
#
# Confusion Matrix:
#      0    1    2
# 0  295   49    0
# 1   72  942   94
# 2    0   77  703
# Epoch: 41
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9285
#   Precision (w):  0.9313
#   Recall (w):     0.9285
#   Precision (per class):  ['0.8630', '0.9635', '0.9143']
#   Recall (per class):  ['0.9715', '0.8876', '0.9663']
#   F1 (macro):     0.9259
#   F1 (weighted):  0.9284
#
# Confusion Matrix:
#       0     1     2
# 0  1398    41     0
# 1   222  4510   349
# 2     0   130  3723
# Val:
#   Metrics:
#   Accuracy:       0.8611
#   Precision (w):  0.8644
#   Recall (w):     0.8611
#   Precision (per class):  ['0.8282', '0.8990', '0.8312']
#   Recall (per class):  ['0.8547', '0.8114', '0.9346']
#   F1 (macro):     0.8580
#   F1 (weighted):  0.8606
#
# Confusion Matrix:
#      0    1    2
# 0  294   50    0
# 1   61  899  148
# 2    0   51  729
# Epochs without improvements - 1
# Epoch: 42
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9288
#   Precision (w):  0.9321
#   Recall (w):     0.9288
#   Precision (per class):  ['0.8769', '0.9699', '0.9030']
#   Recall (per class):  ['0.9750', '0.8819', '0.9733']
#   F1 (macro):     0.9280
#   F1 (weighted):  0.9286
#
# Confusion Matrix:
#       0     1     2
# 0  1403    36     0
# 1   197  4481   403
# 2     0   103  3750
# Val:
#   Metrics:
#   Accuracy:       0.8620
#   Precision (w):  0.8666
#   Recall (w):     0.8620
#   Precision (per class):  ['0.8305', '0.9073', '0.8248']
#   Recall (per class):  ['0.8547', '0.8042', '0.9474']
#   F1 (macro):     0.8590
#   F1 (weighted):  0.8613
#
# Confusion Matrix:
#      0    1    2
# 0  294   50    0
# 1   60  891  157
# 2    0   41  739
# Epochs without improvements - 2
# Epoch: 43
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9308
#   Precision (w):  0.9332
#   Recall (w):     0.9308
#   Precision (per class):  ['0.8814', '0.9644', '0.9113']
#   Recall (per class):  ['0.9757', '0.8916', '0.9657']
#   F1 (macro):     0.9301
#   F1 (weighted):  0.9307
#
# Confusion Matrix:
#       0     1     2
# 0  1404    35     0
# 1   189  4530   362
# 2     0   132  3721
# Val:
#   Metrics:
#   Accuracy:       0.8589
#   Precision (w):  0.8624
#   Recall (w):     0.8589
#   Precision (per class):  ['0.8305', '0.8977', '0.8264']
#   Recall (per class):  ['0.8401', '0.8078', '0.9397']
#   F1 (macro):     0.8550
#   F1 (weighted):  0.8582
#
# Confusion Matrix:
#      0    1    2
# 0  289   55    0
# 1   59  895  154
# 2    0   47  733
# Epochs without improvements - 3
# Epoch: 44
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9334
#   Precision (w):  0.9348
#   Recall (w):     0.9334
#   Precision (per class):  ['0.8830', '0.9563', '0.9257']
#   Recall (per class):  ['0.9701', '0.9053', '0.9567']
#   F1 (macro):     0.9318
#   F1 (weighted):  0.9334
#
# Confusion Matrix:
#       0     1     2
# 0  1396    43     0
# 1   185  4600   296
# 2     0   167  3686
# Val:
#   Metrics:
#   Accuracy:       0.8616
#   Precision (w):  0.8634
#   Recall (w):     0.8616
#   Precision (per class):  ['0.8348', '0.8890', '0.8395']
#   Recall (per class):  ['0.8372', '0.8240', '0.9256']
#   F1 (macro):     0.8573
#   F1 (weighted):  0.8611
#
# Confusion Matrix:
#      0    1    2
# 0  288   56    0
# 1   57  913  138
# 2    0   58  722
# Epochs without improvements - 4
# Epoch: 45
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9061
#   Precision (w):  0.9160
#   Recall (w):     0.9061
#   Precision (per class):  ['0.8857', '0.9795', '0.8436']
#   Recall (per class):  ['0.9694', '0.8256', '0.9886']
#   F1 (macro):     0.9107
#   F1 (weighted):  0.9054
#
# Confusion Matrix:
#       0     1     2
# 0  1395    44     0
# 1   180  4195   706
# 2     0    44  3809
# Val:
#   Metrics:
#   Accuracy:       0.8347
#   Precision (w):  0.8470
#   Recall (w):     0.8347
#   Precision (per class):  ['0.8215', '0.9083', '0.7710']
#   Recall (per class):  ['0.8430', '0.7419', '0.9628']
#   F1 (macro):     0.8351
#   F1 (weighted):  0.8329
#
# Confusion Matrix:
#      0    1    2
# 0  290   54    0
# 1   63  822  223
# 2    0   29  751
# Epochs without improvements - 5
# Epoch: 46
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9348
#   Precision (w):  0.9375
#   Recall (w):     0.9348
#   Precision (per class):  ['0.8786', '0.9701', '0.9165']
#   Recall (per class):  ['0.9805', '0.8945', '0.9709']
#   F1 (macro):     0.9335
#   F1 (weighted):  0.9347
#
# Confusion Matrix:
#       0     1     2
# 0  1411    28     0
# 1   195  4545   341
# 2     0   112  3741
# Val:
#   Metrics:
#   Accuracy:       0.8602
#   Precision (w):  0.8640
#   Recall (w):     0.8602
#   Precision (per class):  ['0.8202', '0.9012', '0.8303']
#   Recall (per class):  ['0.8488', '0.8069', '0.9410']
#   F1 (macro):     0.8560
#   F1 (weighted):  0.8595
#
# Confusion Matrix:
#      0    1    2
# 0  292   52    0
# 1   64  894  150
# 2    0   46  734
# Epochs without improvements - 6
# Epoch: 47
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9402
#   Precision (w):  0.9419
#   Recall (w):     0.9402
#   Precision (per class):  ['0.8720', '0.9598', '0.9443']
#   Recall (per class):  ['0.9847', '0.9164', '0.9551']
#   F1 (macro):     0.9374
#   F1 (weighted):  0.9403
#
# Confusion Matrix:
#       0     1     2
# 0  1417    22     0
# 1   208  4656   217
# 2     0   173  3680
# Val:
#   Metrics:
#   Accuracy:       0.8714
#   Precision (w):  0.8727
#   Recall (w):     0.8714
#   Precision (per class):  ['0.8142', '0.8936', '0.8688']
#   Recall (per class):  ['0.8663', '0.8412', '0.9167']
#   F1 (macro):     0.8660
#   F1 (weighted):  0.8713
#
# Confusion Matrix:
#      0    1    2
# 0  298   46    0
# 1   68  932  108
# 2    0   65  715
# Epoch: 48
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9351
#   Precision (w):  0.9373
#   Recall (w):     0.9351
#   Precision (per class):  ['0.8631', '0.9344', '0.9688']
#   Recall (per class):  ['0.9903', '0.9331', '0.9172']
#   F1 (macro):     0.9328
#   F1 (weighted):  0.9353
#
# Confusion Matrix:
#       0     1     2
# 0  1425    14     0
# 1   226  4741   114
# 2     0   319  3534
# Val:
#   Metrics:
#   Accuracy:       0.8759
#   Precision (w):  0.8770
#   Recall (w):     0.8759
#   Precision (per class):  ['0.8076', '0.8760', '0.9090']
#   Recall (per class):  ['0.8663', '0.8736', '0.8833']
#   F1 (macro):     0.8689
#   F1 (weighted):  0.8762
#
# Confusion Matrix:
#      0    1    2
# 0  298   46    0
# 1   71  968   69
# 2    0   91  689
# Epoch: 49
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9309
#   Precision (w):  0.9345
#   Recall (w):     0.9309
#   Precision (per class):  ['0.8973', '0.9741', '0.8960']
#   Recall (per class):  ['0.9715', '0.8823', '0.9798']
#   F1 (macro):     0.9316
#   F1 (weighted):  0.9307
#
# Confusion Matrix:
#       0     1     2
# 0  1398    41     0
# 1   160  4483   438
# 2     0    78  3775
# Val:
#   Metrics:
#   Accuracy:       0.8548
#   Precision (w):  0.8606
#   Recall (w):     0.8548
#   Precision (per class):  ['0.8291', '0.9050', '0.8116']
#   Recall (per class):  ['0.8459', '0.7906', '0.9500']
#   F1 (macro):     0.8522
#   F1 (weighted):  0.8539
#
# Confusion Matrix:
#      0    1    2
# 0  291   53    0
# 1   60  876  172
# 2    0   39  741
# Epochs without improvements - 1
# Epoch: 50
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9424
#   Precision (w):  0.9445
#   Recall (w):     0.9424
#   Precision (per class):  ['0.8699', '0.9663', '0.9435']
#   Recall (per class):  ['0.9896', '0.9144', '0.9618']
#   F1 (macro):     0.9394
#   F1 (weighted):  0.9425
#
# Confusion Matrix:
#       0     1     2
# 0  1424    15     0
# 1   213  4646   222
# 2     0   147  3706
# Val:
#   Metrics:
#   Accuracy:       0.8669
#   Precision (w):  0.8687
#   Recall (w):     0.8669
#   Precision (per class):  ['0.8144', '0.8948', '0.8555']
#   Recall (per class):  ['0.8547', '0.8294', '0.9256']
#   F1 (macro):     0.8614
#   F1 (weighted):  0.8666
#
# Confusion Matrix:
#      0    1    2
# 0  294   50    0
# 1   67  919  122
# 2    0   58  722
# Epochs without improvements - 2
# Epoch: 51
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9154
#   Precision (w):  0.9222
#   Recall (w):     0.9154
#   Precision (per class):  ['0.7753', '0.9291', '0.9680']
#   Recall (per class):  ['0.9951', '0.8955', '0.9118']
#   F1 (macro):     0.9075
#   F1 (weighted):  0.9164
#
# Confusion Matrix:
#       0     1     2
# 0  1432     7     0
# 1   415  4550   116
# 2     0   340  3513
# Val:
#   Metrics:
#   Accuracy:       0.8710
#   Precision (w):  0.8764
#   Recall (w):     0.8710
#   Precision (per class):  ['0.7453', '0.8935', '0.9099']
#   Recall (per class):  ['0.9186', '0.8403', '0.8936']
#   F1 (macro):     0.8635
#   F1 (weighted):  0.8719
#
# Confusion Matrix:
#      0    1    2
# 0  316   28    0
# 1  108  931   69
# 2    0   83  697
# Epochs without improvements - 3
# Epoch: 52
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9361
#   Precision (w):  0.9392
#   Recall (w):     0.9361
#   Precision (per class):  ['0.8352', '0.9543', '0.9582']
#   Recall (per class):  ['0.9931', '0.9132', '0.9450']
#   F1 (macro):     0.9307
#   F1 (weighted):  0.9365
#
# Confusion Matrix:
#       0     1     2
# 0  1429    10     0
# 1   282  4640   159
# 2     0   212  3641
# Val:
#   Metrics:
#   Accuracy:       0.8714
#   Precision (w):  0.8737
#   Recall (w):     0.8714
#   Precision (per class):  ['0.7933', '0.8966', '0.8765']
#   Recall (per class):  ['0.8924', '0.8375', '0.9103']
#   F1 (macro):     0.8664
#   F1 (weighted):  0.8715
#
# Confusion Matrix:
#      0    1    2
# 0  307   37    0
# 1   80  928  100
# 2    0   70  710
# Epochs without improvements - 4
# Epoch: 53
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9404
#   Precision (w):  0.9431
#   Recall (w):     0.9404
#   Precision (per class):  ['0.8622', '0.9711', '0.9365']
#   Recall (per class):  ['0.9910', '0.9053', '0.9678']
#   F1 (macro):     0.9370
#   F1 (weighted):  0.9405
#
# Confusion Matrix:
#       0     1     2
# 0  1426    13     0
# 1   228  4600   253
# 2     0   124  3729
# Val:
#   Metrics:
#   Accuracy:       0.8714
#   Precision (w):  0.8743
#   Recall (w):     0.8714
#   Precision (per class):  ['0.8108', '0.9076', '0.8550']
#   Recall (per class):  ['0.8721', '0.8249', '0.9372']
#   F1 (macro):     0.8663
#   F1 (weighted):  0.8711
#
# Confusion Matrix:
#      0    1    2
# 0  300   44    0
# 1   70  914  124
# 2    0   49  731
# Epochs without improvements - 5
# Epoch: 54
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9402
#   Precision (w):  0.9431
#   Recall (w):     0.9402
#   Precision (per class):  ['0.8947', '0.9788', '0.9142']
#   Recall (per class):  ['0.9861', '0.8975', '0.9795']
#   F1 (macro):     0.9401
#   F1 (weighted):  0.9401
#
# Confusion Matrix:
#       0     1     2
# 0  1419    20     0
# 1   167  4560   354
# 2     0    79  3774
# Val:
#   Metrics:
#   Accuracy:       0.8678
#   Precision (w):  0.8715
#   Recall (w):     0.8678
#   Precision (per class):  ['0.8319', '0.9085', '0.8364']
#   Recall (per class):  ['0.8634', '0.8159', '0.9436']
#   F1 (macro):     0.8646
#   F1 (weighted):  0.8673
#
# Confusion Matrix:
#      0    1    2
# 0  297   47    0
# 1   60  904  144
# 2    0   44  736
# Epochs without improvements - 6
# Epoch: 55
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9454
#   Precision (w):  0.9462
#   Recall (w):     0.9454
#   Precision (per class):  ['0.9110', '0.9633', '0.9368']
#   Recall (per class):  ['0.9673', '0.9238', '0.9657']
#   F1 (macro):     0.9442
#   F1 (weighted):  0.9454
#
# Confusion Matrix:
#       0     1     2
# 0  1392    47     0
# 1   136  4694   251
# 2     0   132  3721
# Val:
#   Metrics:
#   Accuracy:       0.8692
#   Precision (w):  0.8698
#   Recall (w):     0.8692
#   Precision (per class):  ['0.8611', '0.8835', '0.8543']
#   Recall (per class):  ['0.8110', '0.8484', '0.9244']
#   F1 (macro):     0.8629
#   F1 (weighted):  0.8687
#
# Confusion Matrix:
#      0    1    2
# 0  279   65    0
# 1   45  940  123
# 2    0   59  721
# Epochs without improvements - 7
# Epoch: 56
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9391
#   Precision (w):  0.9422
#   Recall (w):     0.9391
#   Precision (per class):  ['0.8934', '0.9793', '0.9115']
#   Recall (per class):  ['0.9840', '0.8945', '0.9811']
#   F1 (macro):     0.9388
#   F1 (weighted):  0.9389
#
# Confusion Matrix:
#       0     1     2
# 0  1416    23     0
# 1   169  4545   367
# 2     0    73  3780
# Val:
#   Metrics:
#   Accuracy:       0.8660
#   Precision (w):  0.8701
#   Recall (w):     0.8660
#   Precision (per class):  ['0.8277', '0.9090', '0.8335']
#   Recall (per class):  ['0.8517', '0.8114', '0.9500']
#   F1 (macro):     0.8616
#   F1 (weighted):  0.8653
#
# Confusion Matrix:
#      0    1    2
# 0  293   51    0
# 1   61  899  148
# 2    0   39  741
# Epochs without improvements - 8
# Epoch: 57
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9438
#   Precision (w):  0.9464
#   Recall (w):     0.9438
#   Precision (per class):  ['0.8503', '0.9616', '0.9623']
#   Recall (per class):  ['0.9944', '0.9221', '0.9535']
#   F1 (macro):     0.9387
#   F1 (weighted):  0.9441
#
# Confusion Matrix:
#       0     1     2
# 0  1431     8     0
# 1   252  4685   144
# 2     0   179  3674
# Val:
#   Metrics:
#   Accuracy:       0.8737
#   Precision (w):  0.8754
#   Recall (w):     0.8737
#   Precision (per class):  ['0.7895', '0.8941', '0.8868']
#   Recall (per class):  ['0.8721', '0.8457', '0.9141']
#   F1 (macro):     0.8661
#   F1 (weighted):  0.8738
#
# Confusion Matrix:
#      0    1    2
# 0  300   44    0
# 1   80  937   91
# 2    0   67  713
# Epochs without improvements - 9
# Epoch: 58
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9348
#   Precision (w):  0.9387
#   Recall (w):     0.9348
#   Precision (per class):  ['0.9066', '0.9800', '0.8962']
#   Recall (per class):  ['0.9785', '0.8851', '0.9842']
#   F1 (macro):     0.9365
#   F1 (weighted):  0.9346
#
# Confusion Matrix:
#       0     1     2
# 0  1408    31     0
# 1   145  4497   439
# 2     0    61  3792
# Val:
#   Metrics:
#   Accuracy:       0.8584
#   Precision (w):  0.8643
#   Recall (w):     0.8584
#   Precision (per class):  ['0.8223', '0.9099', '0.8179']
#   Recall (per class):  ['0.8343', '0.7933', '0.9615']
#   F1 (macro):     0.8533
#   F1 (weighted):  0.8573
#
# Confusion Matrix:
#      0    1    2
# 0  287   57    0
# 1   62  879  167
# 2    0   30  750
# Epochs without improvements - 10
# Epoch: 59
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9556
#   Precision (w):  0.9562
#   Recall (w):     0.9556
#   Precision (per class):  ['0.9165', '0.9707', '0.9521']
#   Recall (per class):  ['0.9833', '0.9376', '0.9689']
#   F1 (macro):     0.9543
#   F1 (weighted):  0.9556
#
# Confusion Matrix:
#       0     1     2
# 0  1415    24     0
# 1   129  4764   188
# 2     0   120  3733
# Val:
#   Metrics:
#   Accuracy:       0.8768
#   Precision (w):  0.8771
#   Recall (w):     0.8768
#   Precision (per class):  ['0.8387', '0.8918', '0.8732']
#   Recall (per class):  ['0.8314', '0.8556', '0.9269']
#   F1 (macro):     0.8692
#   F1 (weighted):  0.8765
#
# Confusion Matrix:
#      0    1    2
# 0  286   58    0
# 1   55  948  105
# 2    0   57  723
# Epoch: 60
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9515
#   Precision (w):  0.9528
#   Recall (w):     0.9515
#   Precision (per class):  ['0.8989', '0.9735', '0.9457']
#   Recall (per class):  ['0.9882', '0.9262', '0.9712']
#   F1 (macro):     0.9496
#   F1 (weighted):  0.9515
#
# Confusion Matrix:
#       0     1     2
# 0  1422    17     0
# 1   160  4706   215
# 2     0   111  3742
# Val:
#   Metrics:
#   Accuracy:       0.8741
#   Precision (w):  0.8755
#   Recall (w):     0.8741
#   Precision (per class):  ['0.8267', '0.9003', '0.8619']
#   Recall (per class):  ['0.8459', '0.8394', '0.9359']
#   F1 (macro):     0.8674
#   F1 (weighted):  0.8737
#
# Confusion Matrix:
#      0    1    2
# 0  291   53    0
# 1   61  930  117
# 2    0   50  730
# Epochs without improvements - 1
# Epoch: 61
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9397
#   Precision (w):  0.9423
#   Recall (w):     0.9397
#   Precision (per class):  ['0.8565', '0.9417', '0.9751']
#   Recall (per class):  ['0.9951', '0.9349', '0.9255']
#   F1 (macro):     0.9362
#   F1 (weighted):  0.9401
#
# Confusion Matrix:
#       0     1     2
# 0  1432     7     0
# 1   240  4750    91
# 2     0   287  3566
# Val:
#   Metrics:
#   Accuracy:       0.8777
#   Precision (w):  0.8799
#   Recall (w):     0.8777
#   Precision (per class):  ['0.7933', '0.8813', '0.9160']
#   Recall (per class):  ['0.8924', '0.8709', '0.8808']
#   F1 (macro):     0.8714
#   F1 (weighted):  0.8782
#
# Confusion Matrix:
#      0    1    2
# 0  307   37    0
# 1   80  965   63
# 2    0   93  687
# Epoch: 62
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9506
#   Precision (w):  0.9528
#   Recall (w):     0.9506
#   Precision (per class):  ['0.9088', '0.9835', '0.9287']
#   Recall (per class):  ['0.9903', '0.9146', '0.9834']
#   F1 (macro):     0.9503
#   F1 (weighted):  0.9506
#
# Confusion Matrix:
#       0     1     2
# 0  1425    14     0
# 1   143  4647   291
# 2     0    64  3789
# Val:
#   Metrics:
#   Accuracy:       0.8683
#   Precision (w):  0.8714
#   Recall (w):     0.8683
#   Precision (per class):  ['0.8267', '0.9062', '0.8417']
#   Recall (per class):  ['0.8459', '0.8195', '0.9474']
#   F1 (macro):     0.8628
#   F1 (weighted):  0.8676
#
# Confusion Matrix:
#      0    1    2
# 0  291   53    0
# 1   61  908  139
# 2    0   41  739
# Epochs without improvements - 1
# Epoch: 63
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9502
#   Precision (w):  0.9516
#   Recall (w):     0.9502
#   Precision (per class):  ['0.8785', '0.9597', '0.9683']
#   Recall (per class):  ['0.9903', '0.9376', '0.9517']
#   F1 (macro):     0.9465
#   F1 (weighted):  0.9503
#
# Confusion Matrix:
#       0     1     2
# 0  1425    14     0
# 1   197  4764   120
# 2     0   186  3667
# Val:
#   Metrics:
#   Accuracy:       0.8759
#   Precision (w):  0.8770
#   Recall (w):     0.8759
#   Precision (per class):  ['0.8076', '0.8938', '0.8837']
#   Recall (per class):  ['0.8663', '0.8511', '0.9154']
#   F1 (macro):     0.8690
#   F1 (weighted):  0.8759
#
# Confusion Matrix:
#      0    1    2
# 0  298   46    0
# 1   71  943   94
# 2    0   66  714
# Epochs without improvements - 2
# Epoch: 64
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9332
#   Precision (w):  0.9375
#   Recall (w):     0.9332
#   Precision (per class):  ['0.8212', '0.9400', '0.9775']
#   Recall (per class):  ['0.9958', '0.9225', '0.9240']
#   F1 (macro):     0.9271
#   F1 (weighted):  0.9338
#
# Confusion Matrix:
#       0     1     2
# 0  1433     6     0
# 1   312  4687    82
# 2     0   293  3560
# Val:
#   Metrics:
#   Accuracy:       0.8737
#   Precision (w):  0.8761
#   Recall (w):     0.8737
#   Precision (per class):  ['0.7859', '0.8896', '0.8968']
#   Recall (per class):  ['0.9070', '0.8511', '0.8910']
# ...
#
# Confusion Matrix:
#      0    1    2
# 0  293   51    0
# 1   50  913  145
# 2    0   41  739
# Epochs without improvements - 9
# Epoch: 79
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9529
#   Precision (w):  0.9543
#   Recall (w):     0.9529
#   Precision (per class):  ['0.9185', '0.9392', '0.9877']
#   Recall (per class):  ['0.9944', '0.9663', '0.9195']
#   F1 (macro):     0.9533
#   F1 (weighted):  0.9528
#
# Confusion Matrix:
#       0     1     2
# 0  1431     8     0
# 1   127  4910    44
# 2     0   310  3543
# Val:
#   Metrics:
#   Accuracy:       0.8893
#   Precision (w):  0.8905
#   Recall (w):     0.8893
#   Precision (per class):  ['0.8301', '0.8806', '0.9313']
#   Recall (per class):  ['0.8663', '0.8989', '0.8859']
#   F1 (macro):     0.8818
#   F1 (weighted):  0.8896
#
# Confusion Matrix:
#      0    1    2
# 0  298   46    0
# 1   61  996   51
# 2    0   89  691
# Epoch: 80
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9626
#   Precision (w):  0.9633
#   Recall (w):     0.9626
#   Precision (per class):  ['0.9225', '0.9782', '0.9589']
#   Recall (per class):  ['0.9931', '0.9447', '0.9748']
#   F1 (macro):     0.9615
#   F1 (weighted):  0.9626
#
# Confusion Matrix:
#       0     1     2
# 0  1429    10     0
# 1   120  4800   161
# 2     0    97  3756
# Val:
#   Metrics:
#   Accuracy:       0.8804
#   Precision (w):  0.8817
#   Recall (w):     0.8804
#   Precision (per class):  ['0.8254', '0.9063', '0.8717']
#   Recall (per class):  ['0.8517', '0.8466', '0.9410']
#   F1 (macro):     0.8729
#   F1 (weighted):  0.8801
#
# Confusion Matrix:
#      0    1    2
# 0  293   51    0
# 1   62  938  108
# 2    0   46  734
# Epochs without improvements - 1
# Epoch: 81
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9549
#   Precision (w):  0.9574
#   Recall (w):     0.9549
#   Precision (per class):  ['0.9288', '0.9917', '0.9229']
#   Recall (per class):  ['0.9972', '0.9156', '0.9909']
#   F1 (macro):     0.9565
#   F1 (weighted):  0.9548
#
# Confusion Matrix:
#       0     1     2
# 0  1435     4     0
# 1   110  4652   319
# 2     0    35  3818
# Val:
#   Metrics:
#   Accuracy:       0.8651
#   Precision (w):  0.8694
#   Recall (w):     0.8651
#   Precision (per class):  ['0.8300', '0.9088', '0.8307']
#   Recall (per class):  ['0.8372', '0.8096', '0.9564']
#   F1 (macro):     0.8597
#   F1 (weighted):  0.8643
#
# Confusion Matrix:
#      0    1    2
# 0  288   56    0
# 1   59  897  152
# 2    0   34  746
# Epochs without improvements - 2
# Epoch: 82
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9538
#   Precision (w):  0.9553
#   Recall (w):     0.9538
#   Precision (per class):  ['0.8929', '0.9524', '0.9823']
#   Recall (per class):  ['0.9965', '0.9534', '0.9385']
#   F1 (macro):     0.9516
#   F1 (weighted):  0.9540
#
# Confusion Matrix:
#       0     1     2
# 0  1434     5     0
# 1   172  4844    65
# 2     0   237  3616
# Val:
#   Metrics:
#   Accuracy:       0.8866
#   Precision (w):  0.8874
#   Recall (w):     0.8866
#   Precision (per class):  ['0.8269', '0.8862', '0.9159']
#   Recall (per class):  ['0.8750', '0.8854', '0.8936']
#   F1 (macro):     0.8802
#   F1 (weighted):  0.8869
#
# Confusion Matrix:
#      0    1    2
# 0  301   43    0
# 1   63  981   64
# 2    0   83  697
# Epochs without improvements - 3
# Epoch: 83
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9603
#   Precision (w):  0.9617
#   Recall (w):     0.9603
#   Precision (per class):  ['0.9262', '0.9867', '0.9419']
#   Recall (per class):  ['0.9944', '0.9315', '0.9855']
#   F1 (macro):     0.9602
#   F1 (weighted):  0.9602
#
# Confusion Matrix:
#       0     1     2
# 0  1431     8     0
# 1   114  4733   234
# 2     0    56  3797
# Val:
#   Metrics:
#   Accuracy:       0.8696
#   Precision (w):  0.8720
#   Recall (w):     0.8696
#   Precision (per class):  ['0.8521', '0.9001', '0.8408']
#   Recall (per class):  ['0.8372', '0.8294', '0.9410']
#   F1 (macro):     0.8653
#   F1 (weighted):  0.8691
#
# Confusion Matrix:
#      0    1    2
# 0  288   56    0
# 1   50  919  139
# 2    0   46  734
# Epochs without improvements - 4
# Epoch: 84
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9670
#   Precision (w):  0.9677
#   Recall (w):     0.9670
#   Precision (per class):  ['0.9317', '0.9835', '0.9603']
#   Recall (per class):  ['0.9958', '0.9486', '0.9805']
#   F1 (macro):     0.9663
#   F1 (weighted):  0.9670
#
# Confusion Matrix:
#       0     1     2
# 0  1433     6     0
# 1   105  4820   156
# 2     0    75  3778
# Val:
#   Metrics:
#   Accuracy:       0.8714
#   Precision (w):  0.8730
#   Recall (w):     0.8714
#   Precision (per class):  ['0.8343', '0.8982', '0.8543']
#   Recall (per class):  ['0.8488', '0.8357', '0.9321']
#   F1 (macro):     0.8663
#   F1 (weighted):  0.8710
#
# Confusion Matrix:
#      0    1    2
# 0  292   52    0
# 1   58  926  124
# 2    0   53  727
# Epochs without improvements - 5
# Epoch: 85
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9330
#   Precision (w):  0.9387
#   Recall (w):     0.9330
#   Precision (per class):  ['0.9568', '0.9826', '0.8739']
#   Recall (per class):  ['0.9541', '0.8788', '0.9966']
#   F1 (macro):     0.9382
#   F1 (weighted):  0.9329
#
# Confusion Matrix:
#       0     1     2
# 0  1373    66     0
# 1    62  4465   554
# 2     0    13  3840
# Val:
#   Metrics:
#   Accuracy:       0.8499
#   Precision (w):  0.8586
#   Recall (w):     0.8499
#   Precision (per class):  ['0.8648', '0.9047', '0.7904']
#   Recall (per class):  ['0.7994', '0.7798', '0.9718']
#   F1 (macro):     0.8467
#   F1 (weighted):  0.8485
#
# Confusion Matrix:
#      0    1    2
# 0  275   69    0
# 1   43  864  201
# 2    0   22  758
# Epochs without improvements - 6
# Epoch: 86
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9579
#   Precision (w):  0.9586
#   Recall (w):     0.9579
#   Precision (per class):  ['0.9096', '0.9693', '0.9629']
#   Recall (per class):  ['0.9931', '0.9439', '0.9631']
#   F1 (macro):     0.9563
#   F1 (weighted):  0.9579
#
# Confusion Matrix:
#       0     1     2
# 0  1429    10     0
# 1   142  4796   143
# 2     0   142  3711
# Val:
#   Metrics:
#   Accuracy:       0.8813
#   Precision (w):  0.8819
#   Recall (w):     0.8813
#   Precision (per class):  ['0.8385', '0.8980', '0.8780']
#   Recall (per class):  ['0.8605', '0.8583', '0.9231']
#   F1 (macro):     0.8757
#   F1 (weighted):  0.8811
#
# Confusion Matrix:
#      0    1    2
# 0  296   48    0
# 1   57  951  100
# 2    0   60  720
# Epochs without improvements - 7
# Epoch: 87
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9653
#   Precision (w):  0.9664
#   Recall (w):     0.9653
#   Precision (per class):  ['0.9252', '0.9884', '0.9529']
#   Recall (per class):  ['0.9965', '0.9402', '0.9868']
#   F1 (macro):     0.9642
#   F1 (weighted):  0.9653
#
# Confusion Matrix:
#       0     1     2
# 0  1434     5     0
# 1   116  4777   188
# 2     0    51  3802
# Val:
#   Metrics:
#   Accuracy:       0.8737
#   Precision (w):  0.8759
#   Recall (w):     0.8737
#   Precision (per class):  ['0.8409', '0.9049', '0.8500']
#   Recall (per class):  ['0.8605', '0.8330', '0.9372']
#   F1 (macro):     0.8698
#   F1 (weighted):  0.8733
#
# Confusion Matrix:
#      0    1    2
# 0  296   48    0
# 1   56  923  129
# 2    0   49  731
# Epochs without improvements - 8
# Epoch: 88
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9653
#   Precision (w):  0.9661
#   Recall (w):     0.9653
#   Precision (per class):  ['0.9288', '0.9840', '0.9565']
#   Recall (per class):  ['0.9979', '0.9445', '0.9805']
#   F1 (macro):     0.9648
#   F1 (weighted):  0.9653
#
# Confusion Matrix:
#       0     1     2
# 0  1436     3     0
# 1   110  4799   172
# 2     0    75  3778
# Val:
#   Metrics:
#   Accuracy:       0.8728
#   Precision (w):  0.8744
#   Recall (w):     0.8728
#   Precision (per class):  ['0.8459', '0.8992', '0.8516']
#   Recall (per class):  ['0.8459', '0.8375', '0.9346']
#   F1 (macro):     0.8681
#   F1 (weighted):  0.8724
#
# Confusion Matrix:
#      0    1    2
# 0  291   53    0
# 1   53  928  127
# 2    0   51  729
# Epochs without improvements - 9
# Epoch: 89
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9672
#   Precision (w):  0.9676
#   Recall (w):     0.9672
#   Precision (per class):  ['0.9413', '0.9792', '0.9621']
#   Recall (per class):  ['0.9917', '0.9534', '0.9764']
#   F1 (macro):     0.9670
#   F1 (weighted):  0.9672
#
# Confusion Matrix:
#       0     1     2
# 0  1427    12     0
# 1    89  4844   148
# 2     0    91  3762
# Val:
#   Metrics:
#   Accuracy:       0.8826
#   Precision (w):  0.8830
#   Recall (w):     0.8826
#   Precision (per class):  ['0.8584', '0.8968', '0.8741']
#   Recall (per class):  ['0.8285', '0.8628', '0.9346']
#   F1 (macro):     0.8753
#   F1 (weighted):  0.8822
#
# Confusion Matrix:
#      0    1    2
# 0  285   59    0
# 1   47  956  105
# 2    0   51  729
# Epochs without improvements - 10
# Epoch: 90
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9654
#   Precision (w):  0.9663
#   Recall (w):     0.9654
#   Precision (per class):  ['0.9153', '0.9816', '0.9651']
#   Recall (per class):  ['0.9986', '0.9471', '0.9772']
#   F1 (macro):     0.9634
#   F1 (weighted):  0.9654
#
# Confusion Matrix:
#       0     1     2
# 0  1437     2     0
# 1   133  4812   136
# 2     0    88  3765
# Val:
#   Metrics:
#   Accuracy:       0.8799
#   Precision (w):  0.8811
#   Recall (w):     0.8799
#   Precision (per class):  ['0.8408', '0.9031', '0.8678']
#   Recall (per class):  ['0.8750', '0.8493', '0.9256']
#   F1 (macro):     0.8762
#   F1 (weighted):  0.8797
#
# Confusion Matrix:
#      0    1    2
# 0  301   43    0
# 1   57  941  110
# 2    0   58  722
# Epochs without improvements - 11
# Epoch: 91
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9656
#   Precision (w):  0.9657
#   Recall (w):     0.9656
#   Precision (per class):  ['0.9497', '0.9666', '0.9704']
#   Recall (per class):  ['0.9847', '0.9630', '0.9618']
#   F1 (macro):     0.9659
#   F1 (weighted):  0.9656
#
# Confusion Matrix:
#       0     1     2
# 0  1417    22     0
# 1    75  4893   113
# 2     0   147  3706
# Val:
#   Metrics:
#   Accuracy:       0.8799
#   Precision (w):  0.8797
#   Recall (w):     0.8799
#   Precision (per class):  ['0.8665', '0.8804', '0.8846']
#   Recall (per class):  ['0.8110', '0.8773', '0.9141']
#   F1 (macro):     0.8719
#   F1 (weighted):  0.8796
#
# Confusion Matrix:
#      0    1    2
# 0  279   65    0
# 1   43  972   93
# 2    0   67  713
# Epochs without improvements - 12
# Epoch: 92
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9649
#   Precision (w):  0.9656
#   Recall (w):     0.9649
#   Precision (per class):  ['0.9187', '0.9686', '0.9791']
#   Recall (per class):  ['0.9972', '0.9595', '0.9600']
#   F1 (macro):     0.9633
#   F1 (weighted):  0.9650
#
# Confusion Matrix:
#       0     1     2
# 0  1435     4     0
# 1   127  4875    79
# 2     0   154  3699
# Val:
#   Metrics:
#   Accuracy:       0.8884
#   Precision (w):  0.8893
#   Recall (w):     0.8884
#   Precision (per class):  ['0.8261', '0.9010', '0.9004']
#   Recall (per class):  ['0.8837', '0.8709', '0.9154']
#   F1 (macro):     0.8825
#   F1 (weighted):  0.8885
#
# Confusion Matrix:
#      0    1    2
# 0  304   40    0
# 1   64  965   79
# 2    0   66  714
# Epochs without improvements - 13
# Epoch: 93
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9644
#   Precision (w):  0.9649
#   Recall (w):     0.9644
#   Precision (per class):  ['0.9642', '0.9789', '0.9469']
#   Recall (per class):  ['0.9555', '0.9478', '0.9896']
#   F1 (macro):     0.9636
#   F1 (weighted):  0.9644
#
# Confusion Matrix:
#       0     1     2
# 0  1375    64     0
# 1    51  4816   214
# 2     0    40  3813
# Val:
#   Metrics:
#   Accuracy:       0.8754
#   Precision (w):  0.8776
#   Recall (w):     0.8754
#   Precision (per class):  ['0.9033', '0.8922', '0.8455']
#   Recall (per class):  ['0.7878', '0.8520', '0.9474']
#   F1 (macro):     0.8690
#   F1 (weighted):  0.8747
#
# Confusion Matrix:
#      0    1    2
# 0  271   73    0
# 1   29  944  135
# 2    0   41  739
# Epochs without improvements - 14
# Epoch: 94
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9652
#   Precision (w):  0.9659
#   Recall (w):     0.9652
#   Precision (per class):  ['0.9158', '0.9760', '0.9714']
#   Recall (per class):  ['0.9972', '0.9524', '0.9702']
#   F1 (macro):     0.9632
#   F1 (weighted):  0.9653
#
# Confusion Matrix:
#       0     1     2
# 0  1435     4     0
# 1   132  4839   110
# 2     0   115  3738
# Val:
#   Metrics:
#   Accuracy:       0.8835
#   Precision (w):  0.8847
#   Recall (w):     0.8835
#   Precision (per class):  ['0.8247', '0.9054', '0.8819']
#   Recall (per class):  ['0.8750', '0.8547', '0.9282']
#   F1 (macro):     0.8776
#   F1 (weighted):  0.8834
#
# Confusion Matrix:
#      0    1    2
# 0  301   43    0
# 1   64  947   97
# 2    0   56  724
# Epochs without improvements - 15
# Epoch: 95
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9657
#   Precision (w):  0.9665
#   Recall (w):     0.9657
#   Precision (per class):  ['0.9485', '0.9858', '0.9477']
#   Recall (per class):  ['0.9854', '0.9435', '0.9875']
#   F1 (macro):     0.9660
#   F1 (weighted):  0.9657
#
# Confusion Matrix:
#       0     1     2
# 0  1418    21     0
# 1    77  4794   210
# 2     0    48  3805
# Val:
#   Metrics:
#   Accuracy:       0.8790
#   Precision (w):  0.8806
#   Recall (w):     0.8790
#   Precision (per class):  ['0.8701', '0.9029', '0.8537']
#   Recall (per class):  ['0.8372', '0.8475', '0.9423']
#   F1 (macro):     0.8745
#   F1 (weighted):  0.8786
#
# Confusion Matrix:
#      0    1    2
# 0  288   56    0
# 1   43  939  126
# 2    0   45  735
# Epochs without improvements - 16
# Epoch: 96
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9684
#   Precision (w):  0.9687
#   Recall (w):     0.9684
#   Precision (per class):  ['0.9377', '0.9705', '0.9779']
#   Recall (per class):  ['0.9944', '0.9648', '0.9634']
#   F1 (macro):     0.9678
#   F1 (weighted):  0.9684
#
# Confusion Matrix:
#       0     1     2
# 0  1431     8     0
# 1    95  4902    84
# 2     0   141  3712
# Val:
#   Metrics:
#   Accuracy:       0.8822
#   Precision (w):  0.8820
#   Recall (w):     0.8822
#   Precision (per class):  ['0.8437', '0.8873', '0.8915']
#   Recall (per class):  ['0.8314', '0.8736', '0.9167']
#   F1 (macro):     0.8739
#   F1 (weighted):  0.8820
#
# Confusion Matrix:
#      0    1    2
# 0  286   58    0
# 1   53  968   87
# 2    0   65  715
# Epochs without improvements - 17
# Epoch: 97
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9702
#   Precision (w):  0.9705
#   Recall (w):     0.9702
#   Precision (per class):  ['0.9401', '0.9770', '0.9733']
#   Recall (per class):  ['0.9931', '0.9618', '0.9727']
#   F1 (macro):     0.9694
#   F1 (weighted):  0.9702
#
# Confusion Matrix:
#       0     1     2
# 0  1429    10     0
# 1    91  4887   103
# 2     0   105  3748
# Val:
#   Metrics:
#   Accuracy:       0.8871
#   Precision (w):  0.8872
#   Recall (w):     0.8871
#   Precision (per class):  ['0.8630', '0.8963', '0.8850']
#   Recall (per class):  ['0.8605', '0.8736', '0.9179']
#   F1 (macro):     0.8826
#   F1 (weighted):  0.8870
#
# Confusion Matrix:
#      0    1    2
# 0  296   48    0
# 1   47  968   93
# 2    0   64  716
# Epochs without improvements - 18
# Epoch: 98
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9601
#   Precision (w):  0.9615
#   Recall (w):     0.9601
#   Precision (per class):  ['0.8899', '0.9721', '0.9743']
#   Recall (per class):  ['0.9993', '0.9457', '0.9644']
#   F1 (macro):     0.9565
#   F1 (weighted):  0.9603
#
# Confusion Matrix:
#       0     1     2
# 0  1438     1     0
# 1   178  4805    98
# 2     0   137  3716
# Val:
#   Metrics:
#   Accuracy:       0.8884
#   Precision (w):  0.8893
#   Recall (w):     0.8884
#   Precision (per class):  ['0.8251', '0.9048', '0.8957']
#   Recall (per class):  ['0.8779', '0.8664', '0.9244']
#   F1 (macro):     0.8819
#   F1 (weighted):  0.8885
#
# Confusion Matrix:
#      0    1    2
# 0  302   42    0
# 1   64  960   84
# 2    0   59  721
# Epochs without improvements - 19
# Epoch: 99
# Learning rate: 0.0001
# Train:
#   Metrics:
#   Accuracy:       0.9683
#   Precision (w):  0.9692
#   Recall (w):     0.9683
#   Precision (per class):  ['0.9200', '0.9849', '0.9668']
#   Recall (per class):  ['0.9993', '0.9498', '0.9811']
#   F1 (macro):     0.9663
#   F1 (weighted):  0.9683
#
# Confusion Matrix:
#       0     1     2
# 0  1438     1     0
# 1   125  4826   130
# 2     0    73  3780
# Val:
#   Metrics:
#   Accuracy:       0.8772
#   Precision (w):  0.8784
#   Recall (w):     0.8772
#   Precision (per class):  ['0.8310', '0.9002', '0.8683']
#   Recall (per class):  ['0.8576', '0.8466', '0.9295']
#   F1 (macro):     0.8715
#   F1 (weighted):  0.8770
#
# Confusion Matrix:
#      0    1    2
# 0  295   49    0
# 1   60  938  110
# 2    0   55  725
# Epochs without improvements - 20
# Current LR - 4e-05

# %%
from pathlib import Path
PROJECT_ROOT = Path(r'C:\Python\projects\CGPAPrediction')

# %%
torch.save(model.state_dict(), PROJECT_ROOT / "outputs/models/model_weights.pth")

# %%
def serialize(l):
    res = {}
    for i, e in enumerate(l):
        ne = {}
        for k, v in e.items():
            if isinstance(v, np.ndarray):
                ne[k] = v.tolist()
            else:
                ne[k] = v
        res[i + 1] = ne
    return res

# %%
learning_data
# Out:
# [{'model': 'Unnamed',
#   'accuracy': 0.4443266171792153,
#   'precision_w': 0.49080596251399394,
#   'recall_w': 0.4443266171792153,
#   'precision_per_class': array([0.29149378, 0.58029557, 0.44723305]),
#   'recall_per_class': array([0.39054899, 0.23184413, 0.74461459]),
#   'f1_macro': 0.40798984669293303,
#   'f1_weighted': 0.4161719027494398},
#  {'model': 'Unnamed',
#   'accuracy': 0.43324372759856633,
#   'precision_w': 0.4809436521700903,
#   'recall_w': 0.43324372759856633,
#   'precision_per_class': array([0.31339713, 0.57537155, 0.42069993]),
#   'recall_per_class': array([0.38081395, 0.24458484, 0.72435897]),
#   'f1_macro': 0.4064509692075184,
#   'f1_weighted': 0.40939615615305214},
#  {'model': 'Unnamed',
#   'accuracy': 0.45203894726694305,
#   'precision_w': 0.5338100006977559,
#   'recall_w': 0.45203894726694305,
#   'precision_per_class': array([0.29547498, 0.61958569, 0.50970874]),
#   'recall_per_class': array([0.68519805, 0.12950207, 0.79029328]),
#   'f1_macro': 0.4156155249664375,
#   'f1_weighted': 0.3924068228244293},
#  {'model': 'Unnamed',
#   'accuracy': 0.45474910394265233,
#   'precision_w': 0.512035888293538,
#   'recall_w': 0.45474910394265233,
#   'precision_per_class': array([0.34265734, 0.57875458, 0.49196141]),
#   'recall_per_class': array([0.7122093 , 0.14259928, 0.78461538]),
#   'f1_macro': 0.4320878132924843,
#   'f1_weighted': 0.39623694227338707},
#  {'model': 'Unnamed',
#   'accuracy': 0.5308011182878627,
#   'precision_w': 0.5689145586816813,
#   'recall_w': 0.5308011182878627,
#   'precision_per_class': array([0.38373519, 0.63621533, 0.54932408]),
#   'recall_per_class': array([0.65253648, 0.30702618, 0.78043083]),
#   'f1_macro': 0.5140818631043927,
#   'f1_weighted': 0.5094245302346728},
#  {'model': 'Unnamed',
#   'accuracy': 0.5040322580645161,
#   'precision_w': 0.5301594993197649,
#   'recall_w': 0.5040322580645161,
#   'precision_per_class': array([0.40874525, 0.58015267, 0.51269036]),
#   'recall_per_class': array([0.625     , 0.27436823, 0.77692308]),
#   'f1_macro': 0.49484629874305514,
#   'f1_weighted': 0.4769902171221141},
#  {'model': 'Unnamed',
#   'accuracy': 0.5725441048876891,
#   'precision_w': 0.6018889218730418,
#   'recall_w': 0.5725441048876891,
#   'precision_per_class': array([0.41789819, 0.65821534, 0.59632653]),
#   'recall_per_class': array([0.70743572, 0.39342649, 0.7583701 ]),
#   'f1_macro': 0.5618539973898854,
#   'f1_weighted': 0.5621209522162072},
#  {'model': 'Unnamed',
#   'accuracy': 0.5336021505376344,
#   'precision_w': 0.5619072442790682,
#   'recall_w': 0.5336021505376344,
#   'precision_per_class': array([0.40262172, 0.62006579, 0.54954128]),
#   'recall_per_class': array([0.625     , 0.34025271, 0.76794872]),
#   'f1_macro': 0.5232616937159347,
#   'f1_weighted': 0.5174833439552289},
#  {'model': 'Unnamed',
#   'accuracy': 0.6064783572736913,
#   'precision_w': 0.629825012687775,
#   'recall_w': 0.6064783572736913,
#   'precision_per_class': array([0.45086461, 0.67702227, 0.63442266]),
#   'recall_per_class': array([0.742877  , 0.45463491, 0.75577472]),
#   'f1_macro': 0.5983114839329172,
#   'f1_weighted': 0.6005262566319447},
#  {'model': 'Unnamed',
#   'accuracy': 0.5658602150537635,
#   'precision_w': 0.5869162054070526,
#   'recall_w': 0.5658602150537635,
#   'precision_per_class': array([0.45261122, 0.63841808, 0.57298908]),
#   'recall_per_class': array([0.68023256, 0.40794224, 0.73974359]),
#   'f1_macro': 0.5623754685888723,
#   'f1_weighted': 0.5565620889333696},
#  {'model': 'Unnamed',
#   'accuracy': 0.6387737395160513,
#   'precision_w': 0.6646855352525888,
#   'recall_w': 0.6387737395160513,
#   'precision_per_class': array([0.46396055, 0.68759532, 0.70943992]),
#   'recall_per_class': array([0.84989576, 0.53237552, 0.70023358]),
#   'f1_macro': 0.635054337524123,
#   'f1_weighted': 0.6390183083214807},
#  {'model': 'Unnamed',
#   'accuracy': 0.5851254480286738,
#   'precision_w': 0.6043078513277034,
#   'recall_w': 0.5851254480286738,
#   'precision_per_class': array([0.45979021, 0.64029666, 0.61692127]),
#   'recall_per_class': array([0.76453488, 0.46750903, 0.67307692]),
#   'f1_macro': 0.5861467945299847,
#   'f1_weighted': 0.5817549236241789},
#  {'model': 'Unnamed',
#   'accuracy': 0.6858189530511906,
#   'precision_w': 0.6976574955492085,
#   'recall_w': 0.6858189530511906,
#   'precision_per_class': array([0.55772812, 0.72596739, 0.71258503]),
#   'recall_per_class': array([0.83252259, 0.58708916, 0.76122502]),
#   'f1_macro': 0.6844179844414097,
#   'f1_weighted': 0.6840751346987759},
#  {'model': 'Unnamed',
#   'accuracy': 0.6339605734767025,
#   'precision_w': 0.6408298925822745,
#   'recall_w': 0.6339605734767025,
#   'precision_per_class': array([0.55808656, 0.671875  , 0.63322185]),
#   'recall_per_class': array([0.7122093 , 0.5433213 , 0.72820513]),
#   'f1_macro': 0.6346655781531019,
#   'f1_weighted': 0.6314208372273907},
#  {'model': 'Unnamed',
#   'accuracy': 0.7136797454931071,
#   'precision_w': 0.7272486574787127,
#   'recall_w': 0.7136797454931071,
#   'precision_per_class': array([0.57795572, 0.76559781, 0.73243435]),
#   'recall_per_class': array([0.85267547, 0.60617989, 0.80352972]),
#   'f1_macro': 0.7106336970473942,
#   'f1_weighted': 0.711656507671897},
#  {'model': 'Unnamed',
#   'accuracy': 0.6536738351254481,
#   'precision_w': 0.6629748084691619,
#   'recall_w': 0.6536738351254481,
#   'precision_per_class': array([0.56026786, 0.70046083, 0.65502183]),
#   'recall_per_class': array([0.72965116, 0.54873646, 0.76923077]),
#   'f1_macro': 0.65225672301144,
#   'f1_weighted': 0.650436088861733},
#  {'model': 'Unnamed',
#   'accuracy': 0.7439506410874386,
#   'precision_w': 0.755800629387515,
#   'recall_w': 0.7439506410874386,
#   'precision_per_class': array([0.61958661, 0.79716866, 0.75212064]),
#   'recall_per_class': array([0.87491313, 0.64278685, 0.82844537]),
#   'f1_macro': 0.7418604711713509,
#   'f1_weighted': 0.7421116853587779},
#  {'model': 'Unnamed',
#   'accuracy': 0.6868279569892473,
#   'precision_w': 0.696386362161129,
#   'recall_w': 0.6868279569892473,
#   'precision_per_class': array([0.59593679, 0.73744292, 0.68236583]),
#   'recall_per_class': array([0.76744186, 0.58303249, 0.79871795]),
#   'f1_macro': 0.6860278284944014,
#   'f1_weighted': 0.6838658382912758},
#  {'model': 'Unnamed',
#   'accuracy': 0.7478068061313025,
#   'precision_w': 0.7677522823180857,
#   'recall_w': 0.7478068061313025,
#   'precision_per_class': array([0.66831956, 0.84099037, 0.70830794]),
#   'recall_per_class': array([0.84294649, 0.60165322, 0.90500908]),
#   'f1_macro': 0.7472265946195583,
#   'f1_weighted': 0.7422011489277351},
#  {'model': 'Unnamed',
#   'accuracy': 0.6890681003584229,
#   'precision_w': 0.7127458188836655,
#   'recall_w': 0.6890681003584229,
#   'precision_per_class': array([0.64427861, 0.78426052, 0.64135407]),
#   'recall_per_class': array([0.75290698, 0.52166065, 0.89871795]),
#   'f1_macro': 0.6898200019971235,
#   'f1_weighted': 0.6796346807676471},
#  {'model': 'Unnamed',
#   'accuracy': 0.7789453388605032,
#   'precision_w': 0.7925400229693973,
#   'recall_w': 0.7789453388605032,
#   'precision_per_class': array([0.67557456, 0.85228132, 0.75744212]),
#   'recall_per_class': array([0.87838777, 0.66542019, 0.89151311]),
#   'f1_macro': 0.7767069617863939,
#   'f1_weighted': 0.7762474783739918},
#  {'model': 'Unnamed',
#   'accuracy': 0.7226702508960573,
#   'precision_w': 0.7324390361574895,
#   'recall_w': 0.7226702508960573,
#   'precision_per_class': array([0.65024631, 0.78057143, 0.70031546]),
#   'recall_per_class': array([0.76744186, 0.61642599, 0.85384615]),
#   'f1_macro': 0.7207842233799543,
#   'f1_weighted': 0.7193707935489592},
#  {'model': 'Unnamed',
#   'accuracy': 0.7751855779427359,
#   'precision_w': 0.7911721825089618,
#   'recall_w': 0.7751855779427359,
#   'precision_per_class': array([0.60538117, 0.80966292, 0.83617655]),
#   'recall_per_class': array([0.93815149, 0.70911238, 0.80145341]),
#   'f1_macro': 0.7701337913051116,
#   'f1_weighted': 0.7764355357033184},
#  {'model': 'Unnamed',
#   'accuracy': 0.7316308243727598,
#   'precision_w': 0.7411919467287926,
#   'recall_w': 0.7316308243727598,
#   'precision_per_class': array([0.60706861, 0.7628866 , 0.76952625]),
#   'recall_per_class': array([0.84883721, 0.66787004, 0.77051282]),
#   'f1_macro': 0.7300404326516879,
#   'f1_weighted': 0.7317512099208384},
#  {'model': 'Unnamed',
#   'accuracy': 0.8076737684372891,
#   'precision_w': 0.8151803940477812,
#   'recall_w': 0.8076737684372891,
#   'precision_per_class': array([0.70392585, 0.85556323, 0.80347785]),
#   'recall_per_class': array([0.8971508 , 0.73095847, 0.87542175]),
#   'f1_macro': 0.8050515630337429,
#   'f1_weighted': 0.8068401907586147},
#  {'model': 'Unnamed',
#   'accuracy': 0.7638888888888888,
#   'precision_w': 0.7693584220848827,
#   'recall_w': 0.7638888888888888,
#   'precision_per_class': array([0.68877551, 0.80761099, 0.75055928]),
#   'recall_per_class': array([0.78488372, 0.68953069, 0.86025641]),
#   'f1_macro': 0.7597608686969325,
#   'f1_weighted': 0.7625237559329453},
#  {'model': 'Unnamed',
#   'accuracy': 0.8083485973199653,
#   'precision_w': 0.8213457389884837,
#   'recall_w': 0.8083485973199653,
#   'precision_per_class': array([0.68214286, 0.87621595, 0.80097652]),
#   'recall_per_class': array([0.92911744, 0.70911238, 0.89410849]),
#   'f1_macro': 0.8051811035958956,
#   'f1_weighted': 0.8069571542696985},
#  {'model': 'Unnamed',
#   'accuracy': 0.7526881720430108,
#   'precision_w': 0.7644068318156537,
#   'recall_w': 0.7526881720430108,
#   'precision_per_class': array([0.65661253, 0.8180778 , 0.73570658]),
#   'recall_per_class': array([0.82267442, 0.64530686, 0.87435897]),
#   'f1_macro': 0.7502929015611975,
#   'f1_weighted': 0.7499617352731415},
#  {'model': 'Unnamed',
#   'accuracy': 0.829943121565603,
#   'precision_w': 0.8353301278701951,
#   'recall_w': 0.829943121565603,
#   'precision_per_class': array([0.71718836, 0.86018237, 0.84668018]),
#   'recall_per_class': array([0.9075747 , 0.77976776, 0.86711653]),
#   'f1_macro': 0.8253356711775179,
#   'f1_weighted': 0.8300782194212931},
#  {'model': 'Unnamed',
#   'accuracy': 0.7800179211469535,
#   'precision_w': 0.781963037819668,
#   'recall_w': 0.7800179211469535,
#   'precision_per_class': array([0.72486772, 0.80394089, 0.77592372]),
#   'recall_per_class': array([0.79651163, 0.73646209, 0.83461538]),
#   'f1_macro': 0.777308799363649,
#   'f1_weighted': 0.7796230699921329},
#  {'model': 'Unnamed',
#   'accuracy': 0.7955268485491179,
#   'precision_w': 0.8202352529634799,
#   'recall_w': 0.7955268485491179,
#   'precision_per_class': array([0.5858459 , 0.82805229, 0.89746544]),
#   'recall_per_class': array([0.97220292, 0.73548514, 0.80872048]),
#   'f1_macro': 0.7869781749814441,
#   'f1_weighted': 0.7990361268638729},
#  {'model': 'Unnamed',
#   'accuracy': 0.7692652329749103,
#   'precision_w': 0.7827139735362035,
#   'recall_w': 0.7692652329749103,
#   'precision_per_class': array([0.62252964, 0.8       , 0.82880435]),
#   'recall_per_class': array([0.91569767, 0.71480144, 0.78205128]),
#   'f1_macro': 0.7669768591339537,
#   'f1_weighted': 0.7702573801929612},
#  {'model': 'Unnamed',
#   'accuracy': 0.8455605899932517,
#   'precision_w': 0.8525868051867203,
#   'recall_w': 0.8455605899932517,
#   'precision_per_class': array([0.75731497, 0.8988764 , 0.82712579]),
#   'recall_per_class': array([0.91730368, 0.77150167, 0.91642876]),
#   'f1_macro': 0.84316323539064,
#   'f1_weighted': 0.8447851516789835},
#  {'model': 'Unnamed',
#   'accuracy': 0.7898745519713262,
#   'precision_w': 0.7973796995769402,
#   'recall_w': 0.7898745519713262,
#   'precision_per_class': array([0.74210526, 0.84466019, 0.75459459]),
#   'recall_per_class': array([0.81976744, 0.7066787 , 0.89487179]),
#   'f1_macro': 0.7891023409469319,
#   'f1_weighted': 0.7881989016948573},
#  {'model': 'Unnamed',
#   'accuracy': 0.8460426106237346,
#   'precision_w': 0.8519054934684861,
#   'recall_w': 0.8460426106237346,
#   'precision_per_class': array([0.72835498, 0.87607945, 0.86617005]),
#   'recall_per_class': array([0.93537179, 0.79866168, 0.87516221]),
#   'f1_macro': 0.8417359894025503,
#   'f1_weighted': 0.8463022186458345},
#  {'model': 'Unnamed',
#   'accuracy': 0.8077956989247311,
#   'precision_w': 0.8120919061224298,
#   'recall_w': 0.8077956989247311,
#   'precision_per_class': array([0.7254902 , 0.84327604, 0.80598802]),
#   'recall_per_class': array([0.86046512, 0.75270758, 0.86282051]),
#   'f1_macro': 0.8053642021781551,
#   'f1_weighted': 0.8074447208185531},
#  {'model': 'Unnamed',
#   'accuracy': 0.8520196664417237,
#   'precision_w': 0.860518370316324,
#   'recall_w': 0.8520196664417237,
#   'precision_per_class': array([0.73179872, 0.90424077, 0.85093469]),
#   'recall_per_class': array([0.94996525, 0.78055501, 0.90968077]),
#   'f1_macro': 0.8479722149880216,
#   'f1_weighted': 0.8517180351661586},
#  {'model': 'Unnamed',
#   'accuracy': 0.8086917562724014,
#   'precision_w': 0.8165743777866123,
#   'recall_w': 0.8086917562724014,
#   'precision_per_class': array([0.7480916 , 0.86652314, 0.77582418]),
#   'recall_per_class': array([0.85465116, 0.7265343 , 0.90512821]),
#   'f1_macro': 0.8079033340292469,
#   'f1_weighted': 0.8072958458377556},
#  {'model': 'Unnamed',
#   'accuracy': 0.8484527137761496,
#   'precision_w': 0.8613062956553553,
#   'recall_w': 0.8484527137761496,
#   'precision_per_class': array([0.67790082, 0.87984412, 0.90535763]),
#   'recall_per_class': array([0.97845726, 0.79984255, 0.86400208]),
#   'f1_macro': 0.8410149388722861,
#   'f1_weighted': 0.8499838694272227},
#  {'model': 'Unnamed',
#   'accuracy': 0.8127240143369175,
#   'precision_w': 0.8198734609572285,
#   'recall_w': 0.8127240143369175,
#   'precision_per_class': array([0.69042316, 0.8422619 , 0.84516129]),
#   'recall_per_class': array([0.90116279, 0.76624549, 0.83974359]),
#   'f1_macro': 0.8089141021774046,
#   'f1_weighted': 0.8132537295747858},
#  {'model': 'Unnamed',
#   'accuracy': 0.8604068254121277,
#   'precision_w': 0.8733515408305451,
#   'recall_w': 0.8604068254121277,
#   'precision_per_class': array([0.83156581, 0.94207836, 0.79832654]),
#   'recall_per_class': array([0.92633773, 0.7618579 , 0.96574098]),
#   'f1_macro': 0.8643080912374946,
#   'f1_weighted': 0.8589055988045861},
#  {'model': 'Unnamed',
#   'accuracy': 0.8033154121863799,
#   'precision_w': 0.8197111629912285,
#   'recall_w': 0.8033154121863799,
#   'precision_per_class': array([0.79829545, 0.8867052 , 0.73399015]),
#   'recall_per_class': array([0.81686047, 0.69223827, 0.95512821]),
#   'f1_macro': 0.805017009503212,
#   'f1_weighted': 0.8004933172674342},
#  {'model': 'Unnamed',
#   'accuracy': 0.8761206979658729,
#   'precision_w': 0.8826192764654486,
#   'recall_w': 0.8761206979658729,
#   'precision_per_class': array([0.82147239, 0.93234624, 0.83988054]),
#   'recall_per_class': array([0.9305073 , 0.80555009, 0.94887101]),
#   'f1_macro': 0.8759916438951545,
#   'f1_weighted': 0.8754002355511069},
#  {'model': 'Unnamed',
#   'accuracy': 0.8279569892473119,
#   'precision_w': 0.8367066192760293,
#   'recall_w': 0.8279569892473119,
#   'precision_per_class': array([0.8005618 , 0.88924731, 0.77801268]),
#   'recall_per_class': array([0.82848837, 0.74638989, 0.94358974]),
#   'f1_macro': 0.8262348762033205,
#   'f1_weighted': 0.8264154446458398},
#  {'model': 'Unnamed',
#   'accuracy': 0.8665766894823098,
#   'precision_w': 0.8755434145243477,
#   'recall_w': 0.8665766894823098,
#   'precision_per_class': array([0.72250771, 0.88058472, 0.92605042]),
#   'recall_per_class': array([0.97706741, 0.84176343, 0.8580327 ]),
#   'f1_macro': 0.8607351099717953,
#   'f1_weighted': 0.8677195056219538},
#  {'model': 'Unnamed',
#   'accuracy': 0.8342293906810035,
#   'precision_w': 0.8391270525564597,
#   'recall_w': 0.8342293906810035,
#   'precision_per_class': array([0.72535211, 0.84943182, 0.87466667]),
#   'recall_per_class': array([0.89825581, 0.80956679, 0.84102564]),
#   'f1_macro': 0.8297113583946247,
#   'f1_weighted': 0.8349062635493695},
#  {'model': 'Unnamed',
#   'accuracy': 0.8858575147016292,
#   'precision_w': 0.8903648742786596,
#   'recall_w': 0.8858575147016292,
#   'precision_per_class': array([0.78216704, 0.91732705, 0.89521872]),
#   'recall_per_class': array([0.96316887, 0.8429443 , 0.91357384]),
#   'f1_macro': 0.8820499053877163,
#   'f1_weighted': 0.8860047912988367},
#  {'model': 'Unnamed',
#   'accuracy': 0.839605734767025,
#   'precision_w': 0.8428186863865994,
#   'recall_w': 0.839605734767025,
#   'precision_per_class': array([0.76863753, 0.87350598, 0.83194279]),
#   'recall_per_class': array([0.86918605, 0.79151625, 0.89487179]),
#   'f1_macro': 0.8361928180460317,
#   'f1_weighted': 0.839333712278171},
#  {'model': 'Unnamed',
#   'accuracy': 0.8774703557312253,
#   'precision_w': 0.8856203251509768,
#   'recall_w': 0.8774703557312253,
#   'precision_per_class': array([0.73604591, 0.91305291, 0.90530697]),
#   'recall_per_class': array([0.98054204, 0.82877386, 0.90319232]),
#   'f1_macro': 0.8713349521102466,
#   'f1_weighted': 0.8781306639094324},
#  {'model': 'Unnamed',
#   'accuracy': 0.8387096774193549,
#   'precision_w': 0.8442460143563307,
#   'recall_w': 0.8387096774193549,
#   'precision_per_class': array([0.73975904, 0.8808554 , 0.83832335]),
#   'recall_per_class': array([0.89244186, 0.78068592, 0.8974359 ]),
#   'f1_macro': 0.8345278059909909,
#   'f1_weighted': 0.838526552869646},
#  {'model': 'Unnamed',
#   'accuracy': 0.8803624795141232,
#   'precision_w': 0.8888494454797284,
#   'recall_w': 0.8803624795141232,
#   'precision_per_class': array([0.86640212, 0.94423878, 0.82419035]),
#   'recall_per_class': array([0.91035441, 0.80318835, 0.97093174]),
#   'f1_macro': 0.8824729568158921,
#   'f1_weighted': 0.8795142873163204},
#  {'model': 'Unnamed',
#   'accuracy': 0.8203405017921147,
#   'precision_w': 0.8329399856507982,
#   'recall_w': 0.8203405017921147,
#   'precision_per_class': array([0.85015291, 0.8863388 , 0.74949495]),
#   'recall_per_class': array([0.80813953, 0.73194946, 0.95128205]),
#   'f1_macro': 0.8229372077938241,
#   'f1_weighted': 0.8187191066001674},
#  {'model': 'Unnamed',
#   'accuracy': 0.8901957003759761,
#   'precision_w': 0.8968648682014291,
#   'recall_w': 0.8901957003759761,
#   'precision_per_class': array([0.76480174, 0.9301615 , 0.90227848]),
#   'recall_per_class': array([0.97845726, 0.83881126, 0.92499351]),
#   'f1_macro': 0.8847196995553833,
#   'f1_weighted': 0.8905061708399392},
#  {'model': 'Unnamed',
#   'accuracy': 0.8490143369175627,
#   'precision_w': 0.8542809877961146,
#   'recall_w': 0.8490143369175627,
#   'precision_per_class': array([0.75990099, 0.89376915, 0.83981154]),
#   'recall_per_class': array([0.89244186, 0.78971119, 0.91410256]),
#   'f1_macro': 0.8449211611165325,
#   'f1_weighted': 0.8486820813779845},
#  {'model': 'Unnamed',
#   'accuracy': 0.8904849127542659,
#   'precision_w': 0.896548962030581,
#   'recall_w': 0.8904849127542659,
#   'precision_per_class': array([0.76365603, 0.91657867, 0.91976775]),
#   'recall_per_class': array([0.98123697, 0.85416257, 0.90449001]),
#   'f1_macro': 0.8850720872370609,
#   'f1_weighted': 0.8910724310651164},
#  {'model': 'Unnamed',
#   'accuracy': 0.850358422939068,
#   'precision_w': 0.8537327287111197,
#   'recall_w': 0.850358422939068,
#   'precision_per_class': array([0.76368159, 0.88015717, 0.85591133]),
#   'recall_per_class': array([0.89244186, 0.80866426, 0.89102564]),
#   'f1_macro': 0.8463564460587861,
#   'f1_weighted': 0.8503995984528856},
#  {'model': 'Unnamed',
#   'accuracy': 0.9003181336161188,
#   'precision_w': 0.905939167864602,
#   'recall_w': 0.9003181336161188,
#   'precision_per_class': array([0.83859223, 0.95319149, 0.86877934]),
#   'recall_per_class': array([0.96038916, 0.83763039, 0.96055022]),
#   'f1_macro': 0.8998043084438202,
#   'f1_weighted': 0.899875292250055},
#  {'model': 'Unnamed',
#   'accuracy': 0.8360215053763441,
#   'precision_w': 0.842873604962766,
#   'recall_w': 0.8360215053763441,
#   'precision_per_class': array([0.81337047, 0.88970588, 0.78935939]),
#   'recall_per_class': array([0.84883721, 0.76444043, 0.93205128]),
#   'f1_macro': 0.835948952875844,
#   'f1_weighted': 0.8349679749146114},
#  {'model': 'Unnamed',
#   'accuracy': 0.8960763520678685,
#   'precision_w': 0.9021987738033924,
#   'recall_w': 0.8960763520678685,
#   'precision_per_class': array([0.85164494, 0.95190788, 0.85552735]),
#   'recall_per_class': array([0.95343989, 0.82975792, 0.96210745]),
#   'f1_macro': 0.8973368044336447,
#   'f1_weighted': 0.8955276621110676},
#  {'model': 'Unnamed',
#   'accuracy': 0.8418458781362007,
#   'precision_w': 0.8487774972307728,
#   'recall_w': 0.8418458781362007,
#   'precision_per_class': array([0.82571429, 0.89528796, 0.79288026]),
#   'recall_per_class': array([0.84011628, 0.77166065, 0.94230769]),
#   'f1_macro': 0.8409676405688872,
#   'f1_weighted': 0.8407778980705266},
#  {'model': 'Unnamed',
#   'accuracy': 0.8965583726983515,
#   'precision_w': 0.9034877666392928,
#   'recall_w': 0.8965583726983515,
#   'precision_per_class': array([0.88992662, 0.95400997, 0.84192825]),
#   'recall_per_class': array([0.92703266, 0.82877386, 0.97456527]),
#   'f1_macro': 0.8994994032027751,
#   'f1_weighted': 0.8960171587262017},
#  {'model': 'Unnamed',
#   'accuracy': 0.8297491039426523,
#   'precision_w': 0.8411243155319538,
#   'recall_w': 0.8297491039426523,
#   'precision_per_class': array([0.85981308, 0.89139785, 0.76146789]),
#   'recall_per_class': array([0.80232558, 0.74819495, 0.95769231]),
#   'f1_macro': 0.8306664927478279,
#   'f1_weighted': 0.8282655972391301},
#  {'model': 'Unnamed',
#   'accuracy': 0.9033066615251133,
#   'precision_w': 0.9088725747413962,
#   'recall_w': 0.9033066615251133,
#   'precision_per_class': array([0.84577723, 0.95635631, 0.86981971]),
#   'recall_per_class': array([0.96038916, 0.84097619, 0.96418375]),
#   'f1_macro': 0.9029945731411165,
#   'f1_weighted': 0.902869377776271},
#  {'model': 'Unnamed',
#   'accuracy': 0.842741935483871,
#   'precision_w': 0.849684496896174,
#   'recall_w': 0.842741935483871,
#   'precision_per_class': array([0.81920904, 0.89716684, 0.79567568]),
#   'recall_per_class': array([0.84302326, 0.77166065, 0.94358974]),
#   'f1_macro': 0.8413276634625863,
#   'f1_weighted': 0.841646150037367},
#  {'model': 'Unnamed',
#   'accuracy': 0.9066808059384942,
#   'precision_w': 0.9112225184374768,
#   'recall_w': 0.9066808059384942,
#   'precision_per_class': array([0.82750445, 0.95088796, 0.89018182]),
#   'recall_per_class': array([0.97011814, 0.85357213, 0.95302362]),
#   'f1_macro': 0.9044305143573906,
#   'f1_weighted': 0.9064835759398553},
#  {'model': 'Unnamed',
#   'accuracy': 0.8436379928315412,
#   'precision_w': 0.8486998908140324,
#   'recall_w': 0.8436379928315412,
#   'precision_per_class': array([0.8       , 0.89083419, 0.81032548]),
#   'recall_per_class': array([0.86046512, 0.78068592, 0.92564103]),
#   'f1_macro': 0.8418052288225133,
#   'f1_weighted': 0.8428592060140547},
#  {'model': 'Unnamed',
#   'accuracy': 0.9115974163694206,
#   'precision_w': 0.916683469321273,
#   'recall_w': 0.9115974163694206,
#   'precision_per_class': array([0.82045322, 0.9571805 , 0.89921913]),
#   'recall_per_class': array([0.98123697, 0.85790199, 0.95639761]),
#   'f1_macro': 0.90847482374412,
#   'f1_weighted': 0.9114880445940825},
#  {'model': 'Unnamed',
#   'accuracy': 0.8517025089605734,
#   'precision_w': 0.8563425618455796,
#   'recall_w': 0.8517025089605734,
#   'precision_per_class': array([0.79373368, 0.8968335 , 0.82643678]),
#   'recall_per_class': array([0.88372093, 0.79241877, 0.92179487]),
#   'f1_macro': 0.8497426355465741,
#   'f1_weighted': 0.8511397612044795},
#  {'model': 'Unnamed',
#   'accuracy': 0.9103441627301648,
#   'precision_w': 0.915024486915048,
#   'recall_w': 0.9103441627301648,
#   'precision_per_class': array([0.86088584, 0.95907985, 0.87714756]),
#   'recall_per_class': array([0.95899931, 0.85337532, 0.96729821]),
#   'f1_macro': 0.9101542522243234,
#   'f1_weighted': 0.9099892333585501},
#  {'model': 'Unnamed',
#   'accuracy': 0.8543906810035843,
#   'precision_w': 0.8611560922037743,
#   'recall_w': 0.8543906810035843,
#   'precision_per_class': array([0.82865169, 0.90909091, 0.80739935]),
#   'recall_per_class': array([0.85755814, 0.78519856, 0.95128205]),
#   'f1_macro': 0.852975709492504,
#   'f1_weighted': 0.8534297356172443},
#  {'model': 'Unnamed',
#   'accuracy': 0.9116938204955172,
#   'precision_w': 0.9168132544682502,
#   'recall_w': 0.9116938204955172,
#   'precision_per_class': array([0.79573513, 0.94602699, 0.92350841]),
#   'recall_per_class': array([0.98540653, 0.86931706, 0.94004672]),
#   'f1_macro': 0.9060757884170876,
#   'f1_weighted': 0.9120314121760896},
#  {'model': 'Unnamed',
#   'accuracy': 0.8629032258064516,
#   'precision_w': 0.8662634482931395,
#   'recall_w': 0.8629032258064516,
#   'precision_per_class': array([0.77664975, 0.89624506, 0.86319613]),
#   'recall_per_class': array([0.88953488, 0.81859206, 0.91410256]),
#   'f1_macro': 0.8576163229735401,
#   'f1_weighted': 0.8628664085671652},
#  {'model': 'Unnamed',
#   'accuracy': 0.9142003277740287,
#   'precision_w': 0.9183244074876796,
#   'recall_w': 0.9142003277740287,
#   'precision_per_class': array([0.81886574, 0.94996779, 0.91374122]),
#   'recall_per_class': array([0.98332175, 0.87069475, 0.94575655]),
#   'f1_macro': 0.9105562976695817,
#   'f1_weighted': 0.9142737043517475},
#  {'model': 'Unnamed',
#   'accuracy': 0.8521505376344086,
#   'precision_w': 0.8560930954717865,
#   'recall_w': 0.8521505376344086,
#   'precision_per_class': array([0.78779841, 0.8937247 , 0.83275663]),
#   'recall_per_class': array([0.86337209, 0.79693141, 0.92564103]),
#   'f1_macro': 0.8477195352866871,
#   'f1_weighted': 0.8516224828076883},
#  {'model': 'Unnamed',
#   'accuracy': 0.9276969054275523,
#   'precision_w': 0.9288424618791163,
#   'recall_w': 0.9276969054275523,
#   'precision_per_class': array([0.88280255, 0.94825088, 0.9204431 ]),
#   'recall_per_class': array([0.96316887, 0.90159417, 0.94887101]),
#   'f1_macro': 0.9266704420437152,
#   'f1_weighted': 0.927658493903292},
#  {'model': 'Unnamed',
#   'accuracy': 0.8655913978494624,
#   'precision_w': 0.8673073802455737,
#   'recall_w': 0.8655913978494624,
#   'precision_per_class': array([0.84730539, 0.89147287, 0.84180139]),
#   'recall_per_class': array([0.82267442, 0.83032491, 0.93461538]),
#   'f1_macro': 0.860135020601222,
#   'f1_weighted': 0.8650350531432364},
#  {'model': 'Unnamed',
#   'accuracy': 0.9215270413573701,
#   'precision_w': 0.9250644434997284,
#   'recall_w': 0.9215270413573701,
#   'precision_per_class': array([0.82033507, 0.94587252, 0.9367384 ]),
#   'recall_per_class': array([0.98679639, 0.89076953, 0.93771087]),
#   'f1_macro': 0.9168726209479193,
#   'f1_weighted': 0.921827192166853},
#  {'model': 'Unnamed',
#   'accuracy': 0.8673835125448028,
#   'precision_w': 0.8694120628387311,
#   'recall_w': 0.8673835125448028,
#   'precision_per_class': array([0.79166667, 0.8911368 , 0.87283951]),
#   'recall_per_class': array([0.88372093, 0.83483755, 0.90641026]),
#   'f1_macro': 0.8621806589275685,
#   'f1_weighted': 0.8674415297707426},
#  {'model': 'Unnamed',
#   'accuracy': 0.9272148847970693,
#   'precision_w': 0.9280256635908836,
#   'recall_w': 0.9272148847970693,
#   'precision_per_class': array([0.88287715, 0.92612293, 0.94739667]),
#   'recall_per_class': array([0.96386379, 0.92521157, 0.91616922]),
#   'f1_macro': 0.9262610069769437,
#   'f1_weighted': 0.9272766337138336},
#  {'model': 'Unnamed',
#   'accuracy': 0.8660394265232975,
#   'precision_w': 0.8659833190525286,
#   'recall_w': 0.8660394265232975,
#   'precision_per_class': array([0.83918129, 0.86672711, 0.87674714]),
#   'recall_per_class': array([0.83430233, 0.86281588, 0.88461538]),
#   'f1_macro': 0.8607218187255823,
#   'f1_weighted': 0.8660019397258799},
#  {'model': 'Unnamed',
#   'accuracy': 0.9227802949966258,
#   'precision_w': 0.9245874674342169,
#   'recall_w': 0.9227802949966258,
#   'precision_per_class': array([0.85075529, 0.93023723, 0.94471154]),
#   'recall_per_class': array([0.97845726, 0.91064751, 0.91798598]),
#   'f1_macro': 0.9205479502517583,
#   'f1_weighted': 0.9229432268448924},
#  {'model': 'Unnamed',
#   'accuracy': 0.8691756272401434,
#   'precision_w': 0.8699812631170981,
#   'recall_w': 0.8691756272401434,
#   'precision_per_class': array([0.80381471, 0.88202247, 0.88205772]),
#   'recall_per_class': array([0.85755814, 0.85018051, 0.90128205]),
#   'f1_macro': 0.8623974158402453,
#   'f1_weighted': 0.8692629775492243},
#  {'model': 'Unnamed',
#   'accuracy': 0.928468138436325,
#   'precision_w': 0.9312601304648208,
#   'recall_w': 0.928468138436325,
#   'precision_per_class': array([0.86296296, 0.96346934, 0.91429273]),
#   'recall_per_class': array([0.97150799, 0.88762055, 0.96626006]),
#   'f1_macro': 0.9258578453291048,
#   'f1_weighted': 0.9283907613452878},
#  {'model': 'Unnamed',
#   'accuracy': 0.8611111111111112,
#   'precision_w': 0.8644048306998886,
#   'recall_w': 0.8611111111111112,
#   'precision_per_class': array([0.82816901, 0.899     , 0.83124287]),
#   'recall_per_class': array([0.85465116, 0.81137184, 0.93461538]),
#   'f1_macro': 0.8580154443868352,
#   'f1_weighted': 0.8605541654344504},
#  {'model': 'Unnamed',
#   'accuracy': 0.9287573508146149,
#   'precision_w': 0.9321377323101412,
#   'recall_w': 0.9287573508146149,
#   'precision_per_class': array([0.876875  , 0.96991342, 0.90296171]),
#   'recall_per_class': array([0.97498263, 0.88191301, 0.97326758]),
#   'f1_macro': 0.9279832436959996,
#   'f1_weighted': 0.9285735426849172},
#  {'model': 'Unnamed',
#   'accuracy': 0.8620071684587813,
#   'precision_w': 0.8666418624695119,
#   'recall_w': 0.8620071684587813,
#   'precision_per_class': array([0.83050847, 0.90733198, 0.82477679]),
#   'recall_per_class': array([0.85465116, 0.80415162, 0.9474359 ]),
#   'f1_macro': 0.858966676972399,
#   'f1_weighted': 0.8612705124235431},
#  {'model': 'Unnamed',
#   'accuracy': 0.9307818374626434,
#   'precision_w': 0.9331929128683908,
#   'recall_w': 0.9307818374626434,
#   'precision_per_class': array([0.88135593, 0.96444539, 0.9113397 ]),
#   'recall_per_class': array([0.97567755, 0.89155678, 0.96574098]),
#   'f1_macro': 0.9301477462819688,
#   'f1_weighted': 0.9306611957804187},
#  {'model': 'Unnamed',
#   'accuracy': 0.8588709677419355,
#   'precision_w': 0.8624100893017318,
#   'recall_w': 0.8588709677419355,
#   'precision_per_class': array([0.83045977, 0.89769308, 0.82638106]),
#   'recall_per_class': array([0.84011628, 0.80776173, 0.93974359]),
#   'f1_macro': 0.8550135084402394,
#   'f1_weighted': 0.8581877526673888},
#  {'model': 'Unnamed',
#   'accuracy': 0.9333847488672515,
#   'precision_w': 0.9347704247690988,
#   'recall_w': 0.9333847488672515,
#   'precision_per_class': array([0.88298545, 0.95634096, 0.92566549]),
#   'recall_per_class': array([0.97011814, 0.9053336 , 0.95665715]),
#   'f1_macro': 0.9318493370623088,
#   'f1_weighted': 0.9333563659217714},
#  {'model': 'Unnamed',
#   'accuracy': 0.8615591397849462,
#   'precision_w': 0.8633562679579482,
#   'recall_w': 0.8615591397849462,
#   'precision_per_class': array([0.83478261, 0.88899708, 0.83953488]),
#   'recall_per_class': array([0.8372093 , 0.82400722, 0.92564103]),
#   'f1_macro': 0.8572504400686336,
#   'f1_weighted': 0.8611115135312639},
#  {'model': 'Unnamed',
#   'accuracy': 0.9061023811819146,
#   'precision_w': 0.9159994472335464,
#   'recall_w': 0.9061023811819146,
#   'precision_per_class': array([0.88571429, 0.97945365, 0.84363234]),
#   'recall_per_class': array([0.96942321, 0.82562488, 0.98858033]),
#   'f1_macro': 0.9106792100538684,
#   'f1_weighted': 0.9054485877112928},
#  {'model': 'Unnamed',
#   'accuracy': 0.8346774193548387,
#   'precision_w': 0.8469558201249763,
#   'recall_w': 0.8346774193548387,
#   'precision_per_class': array([0.82152975, 0.90828729, 0.77104723]),
#   'recall_per_class': array([0.84302326, 0.74187726, 0.96282051]),
#   'f1_macro': 0.835052543534809,
#   'f1_weighted': 0.8329237069589623},
#  {'model': 'Unnamed',
#   'accuracy': 0.9348308107587004,
#   'precision_w': 0.9374890251628554,
#   'recall_w': 0.9348308107587004,
#   'precision_per_class': array([0.87858032, 0.9701174 , 0.91646252]),
#   'recall_per_class': array([0.98054204, 0.89450895, 0.97093174]),
#   'f1_macro': 0.9334855333304461,
#   'f1_weighted': 0.9347292269152371},
#  {'model': 'Unnamed',
#   'accuracy': 0.8602150537634409,
#   'precision_w': 0.863953711816739,
#   'recall_w': 0.8602150537634409,
#   'precision_per_class': array([0.82022472, 0.90120968, 0.83031674]),
#   'recall_per_class': array([0.84883721, 0.80685921, 0.94102564]),
#   'f1_macro': 0.8559752747252748,
#   'f1_weighted': 0.8595439708141321},
#  {'model': 'Unnamed',
#   'accuracy': 0.9402294418201099,
#   'precision_w': 0.941869524093734,
#   'recall_w': 0.9402294418201099,
#   'precision_per_class': array([0.872     , 0.9598021 , 0.94431614]),
#   'recall_per_class': array([0.98471161, 0.91635505, 0.95509992]),
#   'f1_macro': 0.9373958862317155,
#   'f1_weighted': 0.9403171070396056},
#  {'model': 'Unnamed',
#   'accuracy': 0.871415770609319,
#   'precision_w': 0.8726759213730519,
#   'recall_w': 0.871415770609319,
#   'precision_per_class': array([0.81420765, 0.89357622, 0.86877278]),
#   'recall_per_class': array([0.86627907, 0.84115523, 0.91666667]),
#   'f1_macro': 0.8660292204450433,
#   'f1_weighted': 0.871303843578779},
#  {'model': 'Unnamed',
#   'accuracy': 0.9351200231369903,
#   'precision_w': 0.9372557926365529,
#   'recall_w': 0.9351200231369903,
#   'precision_per_class': array([0.86311326, 0.9343713 , 0.96875   ]),
#   'recall_per_class': array([0.99027102, 0.93308404, 0.91720737]),
#   'f1_macro': 0.932777229490703,
#   'f1_weighted': 0.9353209464240806},
#  {'model': 'Unnamed',
#   'accuracy': 0.8758960573476703,
#   'precision_w': 0.8769873270068083,
#   'recall_w': 0.8758960573476703,
#   'precision_per_class': array([0.80758808, 0.8760181 , 0.90897098]),
#   'recall_per_class': array([0.86627907, 0.87364621, 0.88333333]),
#   'f1_macro': 0.8689013219124262,
#   'f1_weighted': 0.8762182323759073},
#  {'model': 'Unnamed',
#   'accuracy': 0.93087824158874,
#   'precision_w': 0.9344704204242195,
#   'recall_w': 0.93087824158874,
#   'precision_per_class': array([0.89730424, 0.97414168, 0.89603608]),
#   'recall_per_class': array([0.97150799, 0.88230663, 0.97975603]),
#   'f1_macro': 0.9316378014774682,
#   'f1_weighted': 0.9306633725562706},
#  {'model': 'Unnamed',
#   'accuracy': 0.8548387096774194,
#   'precision_w': 0.8606391827399024,
#   'recall_w': 0.8548387096774194,
#   'precision_per_class': array([0.82905983, 0.90495868, 0.81161008]),
#   'recall_per_class': array([0.84593023, 0.79061372, 0.95      ]),
#   'f1_macro': 0.8522366249798287,
#   'f1_weighted': 0.8539122579035868},
#  {'model': 'Unnamed',
#   'accuracy': 0.9424467367203316,
#   'precision_w': 0.9444522664737711,
#   'recall_w': 0.9424467367203316,
#   'precision_per_class': array([0.86988393, 0.96630616, 0.94348269]),
#   'recall_per_class': array([0.98957609, 0.91438693, 0.96184791]),
#   'f1_macro': 0.9393614815812326,
#   'f1_weighted': 0.9425311821122528},
#  {'model': 'Unnamed',
#   'accuracy': 0.8669354838709677,
#   'precision_w': 0.8686775519067765,
#   'recall_w': 0.8669354838709677,
#   'precision_per_class': array([0.81440443, 0.89483934, 0.85545024]),
#   'recall_per_class': array([0.85465116, 0.82942238, 0.92564103]),
#   'f1_macro': 0.8613650148367443,
#   'f1_weighted': 0.8666323828324353},
#  {'model': 'Unnamed',
#   'accuracy': 0.9153571772871879,
#   'precision_w': 0.9222476330251864,
#   'recall_w': 0.9153571772871879,
#   'precision_per_class': array([0.77531132, 0.92914029, 0.96803527]),
#   'recall_per_class': array([0.99513551, 0.89549301, 0.91175707]),
#   'f1_macro': 0.9075455092409088,
#   'f1_weighted': 0.9164443290532602},
#  {'model': 'Unnamed',
#   'accuracy': 0.8709677419354839,
#   'precision_w': 0.8763824156416117,
#   'recall_w': 0.8709677419354839,
#   'precision_per_class': array([0.74528302, 0.89347409, 0.90992167]),
#   'recall_per_class': array([0.91860465, 0.84025271, 0.89358974]),
#   'f1_macro': 0.8635483125578721,
#   'f1_weighted': 0.8718524375146539},
#  {'model': 'Unnamed',
#   'accuracy': 0.9360840643979562,
#   'precision_w': 0.9392280636070033,
#   'recall_w': 0.9360840643979562,
#   'precision_per_class': array([0.8351841 , 0.95433978, 0.95815789]),
#   'recall_per_class': array([0.99305073, 0.91320606, 0.94497794]),
#   'f1_macro': 0.930714596570267,
#   'f1_weighted': 0.9364716915209357},
#  {'model': 'Unnamed',
#   'accuracy': 0.871415770609319,
#   'precision_w': 0.8736764035345927,
#   'recall_w': 0.871415770609319,
#   'precision_per_class': array([0.79328165, 0.89661836, 0.87654321]),
#   'recall_per_class': array([0.89244186, 0.83754513, 0.91025641]),
#   'f1_macro': 0.8663675454681273,
#   'f1_weighted': 0.8714859808564275},
#  {'model': 'Unnamed',
#   'accuracy': 0.9404222500723031,
#   'precision_w': 0.9431104273430854,
#   'recall_w': 0.9404222500723031,
#   'precision_per_class': array([0.86215236, 0.97107874, 0.93646409]),
#   'recall_per_class': array([0.99096595, 0.9053336 , 0.96781729]),
#   'f1_macro': 0.9370063629963893,
#   'f1_weighted': 0.9404852116813984},
#  {'model': 'Unnamed',
#   'accuracy': 0.871415770609319,
#   'precision_w': 0.8743138019013343,
#   'recall_w': 0.871415770609319,
#   'precision_per_class': array([0.81081081, 0.90764647, 0.85497076]),
#   'recall_per_class': array([0.87209302, 0.82490975, 0.93717949]),
#   'f1_macro': 0.8662761124576926,
#   'f1_weighted': 0.8710532264714314},
#  {'model': 'Unnamed',
#   'accuracy': 0.9402294418201099,
#   'precision_w': 0.9431306517809271,
#   'recall_w': 0.9402294418201099,
#   'precision_per_class': array([0.89470366, 0.9787508 , 0.91424419]),
#   'recall_per_class': array([0.98610146, 0.89746113, 0.9794965 ]),
#   'f1_macro': 0.9400909781601192,
#   'f1_weighted': 0.9400918085065555},
#  {'model': 'Unnamed',
#   'accuracy': 0.867831541218638,
#   'precision_w': 0.8715115756928234,
#   'recall_w': 0.867831541218638,
#   'precision_per_class': array([0.83193277, 0.90854271, 0.83636364]),
#   'recall_per_class': array([0.86337209, 0.81588448, 0.94358974]),
#   'f1_macro': 0.8646107014840149,
#   'f1_weighted': 0.8672621963113089},
#  {'model': 'Unnamed',
#   'accuracy': 0.9454352646293261,
#   'precision_w': 0.9461873023531185,
#   'recall_w': 0.9454352646293261,
#   'precision_per_class': array([0.91099476, 0.96326698, 0.93680765]),
#   'recall_per_class': array([0.96733843, 0.92383389, 0.96574098]),
#   'f1_macro': 0.9441714289381099,
#   'f1_weighted': 0.9454105232243767},
#  {'model': 'Unnamed',
#   'accuracy': 0.8691756272401434,
#   'precision_w': 0.8698124627649461,
#   'recall_w': 0.8691756272401434,
#   'precision_per_class': array([0.86111111, 0.88345865, 0.8542654 ]),
#   'recall_per_class': array([0.81104651, 0.84837545, 0.92435897]),
#   'f1_macro': 0.8629406900303667,
#   'f1_weighted': 0.8687194702437844},
#  {'model': 'Unnamed',
#   'accuracy': 0.9390725923069507,
#   'precision_w': 0.9422041870415079,
#   'recall_w': 0.9390725923069507,
#   'precision_per_class': array([0.89337539, 0.9793148 , 0.91150229]),
#   'recall_per_class': array([0.98401668, 0.89450895, 0.98105372]),
#   'f1_macro': 0.9388335787811205,
#   'f1_weighted': 0.9389201134289707},
#  {'model': 'Unnamed',
#   'accuracy': 0.8660394265232975,
#   'precision_w': 0.8700897290498583,
#   'recall_w': 0.8660394265232975,
#   'precision_per_class': array([0.82768362, 0.90899899, 0.83352081]),
#   'recall_per_class': array([0.85174419, 0.81137184, 0.95      ]),
#   'f1_macro': 0.8616379209809386,
#   'f1_weighted': 0.8653337172986513},
#  {'model': 'Unnamed',
#   'accuracy': 0.943796394485684,
#   'precision_w': 0.9464178862686767,
#   'recall_w': 0.943796394485684,
#   'precision_per_class': array([0.85026738, 0.96161741, 0.96228392]),
#   'recall_per_class': array([0.99444058, 0.92206259, 0.95354269]),
#   'f1_macro': 0.938679370646911,
#   'f1_weighted': 0.9441147371414175},
#  {'model': 'Unnamed',
#   'accuracy': 0.8736559139784946,
#   'precision_w': 0.8754213277091433,
#   'recall_w': 0.8736559139784946,
#   'precision_per_class': array([0.78947368, 0.89408397, 0.88681592]),
#   'recall_per_class': array([0.87209302, 0.84566787, 0.91410256]),
#   'f1_macro': 0.8660613444551881,
#   'f1_weighted': 0.8738153716019261},
#  {'model': 'Unnamed',
#   'accuracy': 0.9348308107587004,
#   'precision_w': 0.9386870571107443,
#   'recall_w': 0.9348308107587004,
#   'precision_per_class': array([0.90663232, 0.97995206, 0.89624202]),
#   'recall_per_class': array([0.97845726, 0.885062  , 0.98416818]),
#   'f1_macro': 0.9364729909725685,
#   'f1_weighted': 0.9346231171575723},
#  {'model': 'Unnamed',
#   'accuracy': 0.8584229390681004,
#   'precision_w': 0.8642693856166397,
#   'recall_w': 0.8584229390681004,
#   'precision_per_class': array([0.82234957, 0.90993789, 0.81788441]),
#   'recall_per_class': array([0.83430233, 0.7933213 , 0.96153846]),
#   'f1_macro': 0.8532776770588235,
#   'f1_weighted': 0.85733132773761},
#  {'model': 'Unnamed',
#   'accuracy': 0.9555576978694688,
#   'precision_w': 0.9562284070692861,
#   'recall_w': 0.9555576978694688,
#   'precision_per_class': array([0.91645078, 0.97066015, 0.95205305]),
#   'recall_per_class': array([0.98332175, 0.93761071, 0.96885544]),
#   'f1_macro': 0.9543131145084289,
#   'f1_weighted': 0.9555623032879226},
#  {'model': 'Unnamed',
#   'accuracy': 0.8767921146953405,
#   'precision_w': 0.8771213209149306,
#   'recall_w': 0.8767921146953405,
#   'precision_per_class': array([0.83870968, 0.89181562, 0.87318841]),
#   'recall_per_class': array([0.83139535, 0.85559567, 0.92692308]),
#   'f1_macro': 0.8692068300818226,
#   'f1_weighted': 0.8764876326611571},
#  {'model': 'Unnamed',
#   'accuracy': 0.9515087245734117,
#   'precision_w': 0.9528172285439974,
#   'recall_w': 0.9515087245734117,
#   'precision_per_class': array([0.8988622 , 0.97352089, 0.94566591]),
#   'recall_per_class': array([0.98818624, 0.92619563, 0.97119128]),
#   'f1_macro': 0.9496458521772344,
#   'f1_weighted': 0.9515178271717444},
#  {'model': 'Unnamed',
#   'accuracy': 0.8741039426523297,
#   'precision_w': 0.875521130181754,
#   'recall_w': 0.8741039426523297,
#   'precision_per_class': array([0.82670455, 0.90029042, 0.86186541]),
#   'recall_per_class': array([0.84593023, 0.83935018, 0.93589744]),
#   'f1_macro': 0.8674389715678311,
#   'f1_weighted': 0.8737329498515547},
#  {'model': 'Unnamed',
#   'accuracy': 0.939747421189627,
#   'precision_w': 0.9422935633453479,
#   'recall_w': 0.939747421189627,
#   'precision_per_class': array([0.85645933, 0.94171293, 0.97511622]),
#   'recall_per_class': array([0.99513551, 0.93485534, 0.92551259]),
#   'f1_macro': 0.9361810075847562,
#   'f1_weighted': 0.9400535042632011},
#  {'model': 'Unnamed',
#   'accuracy': 0.8776881720430108,
#   'precision_w': 0.8798501388411537,
#   'recall_w': 0.8776881720430108,
#   'precision_per_class': array([0.79328165, 0.88127854, 0.916     ]),
#   'recall_per_class': array([0.89244186, 0.87093863, 0.88076923]),
#   'f1_macro': 0.8713541904919414,
#   'f1_weighted': 0.878183813707737},
#  {'model': 'Unnamed',
#   'accuracy': 0.9506410874385424,
#   'precision_w': 0.9527695251274455,
#   'recall_w': 0.9506410874385424,
#   'precision_per_class': array([0.90880102, 0.98349206, 0.92867647]),
#   'recall_per_class': array([0.99027102, 0.91458374, 0.98338957]),
#   'f1_macro': 0.9502752610846592,
#   'f1_weighted': 0.9505594177612663},
#  {'model': 'Unnamed',
#   'accuracy': 0.8682795698924731,
#   'precision_w': 0.8713965314686598,
#   'recall_w': 0.8682795698924731,
#   'precision_per_class': array([0.82670455, 0.90618762, 0.84168565]),
#   'recall_per_class': array([0.84593023, 0.81949458, 0.9474359 ]),
#   'f1_macro': 0.8627686226918957,
#   'f1_weighted': 0.8676478497017193},
#  {'model': 'Unnamed',
#   'accuracy': 0.9501590668080594,
#   'precision_w': 0.9516457108169641,
#   'recall_w': 0.9501590668080594,
#   'precision_per_class': array([0.87854501, 0.95970991, 0.96831265]),
#   'recall_per_class': array([0.99027102, 0.93761071, 0.95172593]),
#   'f1_macro': 0.9465158433615088,
#   'f1_weighted': 0.9503494286934752},
#  {'model': 'Unnamed',
#   'accuracy': 0.8758960573476703,
#   'precision_w': 0.8769897775811806,
#   'recall_w': 0.8758960573476703,
#   'precision_per_class': array([0.80758808, 0.89383886, 0.88366337]),
#   'recall_per_class': array([0.86627907, 0.85108303, 0.91538462]),
#   'f1_macro': 0.8690286950630024,
#   'f1_weighted': 0.875926570468909},
#  {'model': 'Unnamed',
#   'accuracy': 0.9331919406150583,
#   'precision_w': 0.9374591834523166,
#   'recall_w': 0.9331919406150583,
#   'precision_per_class': array([0.82120344, 0.94003209, 0.9774849 ]),
#   'recall_per_class': array([0.99583044, 0.92245621, 0.92395536]),
#   'f1_macro': 0.9270844974658271,
#   'f1_weighted': 0.9338409734718583},
#  {'model': 'Unnamed',
#   'accuracy': 0.8736559139784946,
#   'precision_w': 0.8761350200775498,
#   'recall_w': 0.8736559139784946,
#   'precision_per_class': array([0.78589421, 0.88962264, 0.89677419]),
#   'recall_per_class': array([0.90697674, 0.85108303, 0.89102564]),
#   'f1_macro': 0.8686407125536816,
#   'f1_weighted': 0.8740130672028256},
#  {'model': 'Unnamed',
#   'accuracy': 0.9478453677817411,
#   'precision_w': 0.9491940095713021,
#   'recall_w': 0.9478453677817411,
#   'precision_per_class': array([0.88592684, 0.95039683, 0.97123656]),
#   'recall_per_class': array([0.99305073, 0.94272781, 0.93771087]),
#   'f1_macro': 0.9457204098986983,
#   'f1_weighted': 0.947979107114881},
#  {'model': 'Unnamed',
#   'accuracy': 0.8817204301075269,
#   'precision_w': 0.8828132425990924,
#   'recall_w': 0.8817204301075269,
#   'precision_per_class': array([0.81016043, 0.89146568, 0.9025641 ]),
#   'recall_per_class': array([0.88081395, 0.86732852, 0.9025641 ]),
#   'f1_macro': 0.8752689058784826,
#   'f1_weighted': 0.8819571258800321},
#  {'model': 'Unnamed',
#   'accuracy': 0.9394582088113371,
#   'precision_w': 0.9434452765220703,
#   'recall_w': 0.9394582088113371,
#   'precision_per_class': array([0.93391188, 0.98412698, 0.89335828]),
#   'recall_per_class': array([0.97220292, 0.89076953, 0.99143525]),
#   'f1_macro': 0.9425472538988305,
#   'f1_weighted': 0.9393120419550515},
#  {'model': 'Unnamed',
#   'accuracy': 0.8597670250896058,
#   'precision_w': 0.8652628443358547,
#   'recall_w': 0.8597670250896058,
#   'precision_per_class': array([0.85365854, 0.90519878, 0.81365114]),
#   'recall_per_class': array([0.81395349, 0.80144404, 0.96282051]),
#   'f1_macro': 0.8551579554853702,
#   'f1_weighted': 0.858687830208839},
#  {'model': 'Unnamed',
#   'accuracy': 0.95864262990456,
#   'precision_w': 0.959597358167423,
#   'recall_w': 0.95864262990456,
#   'precision_per_class': array([0.92173351, 0.97919242, 0.94789831]),
#   'recall_per_class': array([0.99027102, 0.93544578, 0.97742019]),
#   'f1_macro': 0.9580087036281763,
#   'f1_weighted': 0.9586207091961965},
#  {'model': 'Unnamed',
#   'accuracy': 0.8772401433691757,
#   'precision_w': 0.8790894044491575,
#   'recall_w': 0.8772401433691757,
#   'precision_per_class': array([0.83142857, 0.90722656, 0.86013986]),
#   'recall_per_class': array([0.84593023, 0.83844765, 0.94615385]),
#   'f1_macro': 0.8703992640521775,
#   'f1_weighted': 0.8767668208423747},
#  {'model': 'Unnamed',
#   'accuracy': 0.955268485491179,
#   'precision_w': 0.955993121102974,
#   'recall_w': 0.955268485491179,
#   'precision_per_class': array([0.91597178, 0.95273583, 0.97523553]),
#   'recall_per_class': array([0.9923558 , 0.956111  , 0.94030625]),
#   'f1_macro': 0.9548359845232399,
#   'f1_weighted': 0.9552989808604456},
#  {'model': 'Unnamed',
#   'accuracy': 0.8826164874551972,
#   'precision_w': 0.8829100720087063,
#   'recall_w': 0.8826164874551972,
#   'precision_per_class': array([0.82436261, 0.88315217, 0.9083871 ]),
#   'recall_per_class': array([0.84593023, 0.8799639 , 0.9025641 ]),
#   'f1_macro': 0.8740095217501075,
#   'f1_weighted': 0.882737116317681},
#  {'model': 'Unnamed',
#   'accuracy': 0.9467849223946785,
#   'precision_w': 0.9484576844470192,
#   'recall_w': 0.9467849223946785,
#   'precision_per_class': array([0.88654681, 0.9427175 , 0.97914952]),
#   'recall_per_class': array([0.99374566, 0.94902578, 0.9262912 ]),
#   'f1_macro': 0.9449795836992211,
#   'f1_weighted': 0.9469199037639051},
#  {'model': 'Unnamed',
#   'accuracy': 0.8844086021505376,
#   'precision_w': 0.8856181682238412,
#   'recall_w': 0.8844086021505376,
#   'precision_per_class': array([0.8125    , 0.88288288, 0.92175066]),
#   'recall_per_class': array([0.86918605, 0.88447653, 0.89102564]),
#   'f1_macro': 0.8765648003550476,
#   'f1_weighted': 0.8847747895795138},
#  {'model': 'Unnamed',
#   'accuracy': 0.9439892027378772,
#   'precision_w': 0.9463854994464668,
#   'recall_w': 0.9439892027378772,
#   'precision_per_class': array([0.90312301, 0.9789272 , 0.91962981]),
#   'recall_per_class': array([0.98471161, 0.90513678, 0.98001557]),
#   'f1_macro': 0.9438680499599608,
#   'f1_weighted': 0.943878455496455},
#  {'model': 'Unnamed',
#   'accuracy': 0.860663082437276,
#   'precision_w': 0.8640173107783949,
#   'recall_w': 0.860663082437276,
#   'precision_per_class': array([0.82808023, 0.8988989 , 0.83031674]),
#   'recall_per_class': array([0.84011628, 0.81046931, 0.94102564]),
#   'f1_macro': 0.8562210483929752,
#   'f1_weighted': 0.8599890174843066},
#  {'model': 'Unnamed',
#   'accuracy': 0.9550756772389858,
#   'precision_w': 0.9561063972888025,
#   'recall_w': 0.9550756772389858,
#   'precision_per_class': array([0.89899624, 0.95938682, 0.97310969]),
#   'recall_per_class': array([0.99583044, 0.94843535, 0.94861147]),
#   'f1_macro': 0.9531743616250011,
#   'f1_weighted': 0.9551743856039456},
#  {'model': 'Unnamed',
# ...
#   'recall_w': 0.871415770609319,
#   'precision_per_class': array([0.85422741, 0.90845771, 0.83597285]),
#   'recall_per_class': array([0.85174419, 0.82400722, 0.9474359 ]),
#   'f1_macro': 0.86845976738782,
#   'f1_weighted': 0.8708530292259085},
#  {'model': 'Unnamed',
#   'accuracy': 0.9528583823387641,
#   'precision_w': 0.9543409651951519,
#   'recall_w': 0.9528583823387641,
#   'precision_per_class': array([0.91848524, 0.93917368, 0.98773348]),
#   'recall_per_class': array([0.99444058, 0.96634521, 0.91954321]),
#   'f1_macro': 0.9533133430226949,
#   'f1_weighted': 0.95284280092616},
#  {'model': 'Unnamed',
#   'accuracy': 0.889336917562724,
#   'precision_w': 0.8905386401299357,
#   'recall_w': 0.889336917562724,
#   'precision_per_class': array([0.83008357, 0.8806366 , 0.93126685]),
#   'recall_per_class': array([0.86627907, 0.89891697, 0.88589744]),
#   'f1_macro': 0.8818312754863907,
#   'f1_weighted': 0.8896337287617302},
#  {'model': 'Unnamed',
#   'accuracy': 0.9625951990745204,
#   'precision_w': 0.9633045444804326,
#   'recall_w': 0.9625951990745204,
#   'precision_per_class': array([0.92253066, 0.97819442, 0.95889712]),
#   'recall_per_class': array([0.99305073, 0.94469593, 0.97482481]),
#   'f1_macro': 0.9614804626905896,
#   'f1_weighted': 0.9626025062787034},
#  {'model': 'Unnamed',
#   'accuracy': 0.8803763440860215,
#   'precision_w': 0.8817348005952514,
#   'recall_w': 0.8803763440860215,
#   'precision_per_class': array([0.82535211, 0.90628019, 0.87173397]),
#   'recall_per_class': array([0.85174419, 0.8465704 , 0.94102564]),
#   'f1_macro': 0.8729347598583675,
#   'f1_weighted': 0.880055918637647},
#  {'model': 'Unnamed',
#   'accuracy': 0.9548828689867926,
#   'precision_w': 0.9574089951934974,
#   'recall_w': 0.9548828689867926,
#   'precision_per_class': array([0.92880259, 0.99168621, 0.92289098]),
#   'recall_per_class': array([0.99722029, 0.9155678 , 0.99091617]),
#   'f1_macro': 0.9565329762591831,
#   'f1_weighted': 0.9547842702771401},
#  {'model': 'Unnamed',
#   'accuracy': 0.8651433691756273,
#   'precision_w': 0.8693772068758822,
#   'recall_w': 0.8651433691756273,
#   'precision_per_class': array([0.82997118, 0.90881459, 0.83073497]),
#   'recall_per_class': array([0.8372093 , 0.80956679, 0.95641026]),
#   'f1_macro': 0.8596842888252193,
#   'f1_weighted': 0.8642908619728029},
#  {'model': 'Unnamed',
#   'accuracy': 0.95382242359973,
#   'precision_w': 0.9552767877638398,
#   'recall_w': 0.95382242359973,
#   'precision_per_class': array([0.89290162, 0.9524184 , 0.98234175]),
#   'recall_per_class': array([0.99652536, 0.95335564, 0.93848949]),
#   'f1_macro': 0.951557921181542,
#   'f1_weighted': 0.9539693600748682},
#  {'model': 'Unnamed',
#   'accuracy': 0.8866487455197133,
#   'precision_w': 0.8874327149731371,
#   'recall_w': 0.8866487455197133,
#   'precision_per_class': array([0.82692308, 0.88617886, 0.91590013]),
#   'recall_per_class': array([0.875     , 0.88537906, 0.89358974]),
#   'f1_macro': 0.8802228882359072,
#   'f1_weighted': 0.8868879188220438},
#  {'model': 'Unnamed',
#   'accuracy': 0.960281500048202,
#   'precision_w': 0.961666368869264,
#   'recall_w': 0.960281500048202,
#   'precision_per_class': array([0.92621359, 0.98665833, 0.94194989]),
#   'recall_per_class': array([0.99444058, 0.93150955, 0.98546587]),
#   'f1_macro': 0.9602076916184151,
#   'f1_weighted': 0.9602350286895452},
#  {'model': 'Unnamed',
#   'accuracy': 0.8696236559139785,
#   'precision_w': 0.8719661770747071,
#   'recall_w': 0.8696236559139785,
#   'precision_per_class': array([0.85207101, 0.90009794, 0.84077892]),
#   'recall_per_class': array([0.8372093 , 0.82942238, 0.94102564]),
#   'f1_macro': 0.865324388520321,
#   'f1_weighted': 0.8690825042073625},
#  {'model': 'Unnamed',
#   'accuracy': 0.9670297888749638,
#   'precision_w': 0.9677042198514155,
#   'recall_w': 0.9670297888749638,
#   'precision_per_class': array([0.93172952, 0.98347276, 0.9603457 ]),
#   'recall_per_class': array([0.99583044, 0.94863216, 0.98053465]),
#   'f1_macro': 0.966262548251197,
#   'f1_weighted': 0.9670262725388199},
#  {'model': 'Unnamed',
#   'accuracy': 0.871415770609319,
#   'precision_w': 0.8729829124364039,
#   'recall_w': 0.871415770609319,
#   'precision_per_class': array([0.83428571, 0.89815713, 0.85428907]),
#   'recall_per_class': array([0.84883721, 0.83574007, 0.93205128]),
#   'f1_macro': 0.8662671107031078,
#   'f1_weighted': 0.8710404646611648},
#  {'model': 'Unnamed',
#   'accuracy': 0.9329991323628651,
#   'precision_w': 0.938658147281757,
#   'recall_w': 0.9329991323628651,
#   'precision_per_class': array([0.95679443, 0.98261444, 0.87391898]),
#   'recall_per_class': array([0.95413482, 0.87876402, 0.99662601]),
#   'f1_macro': 0.9381675679657332,
#   'f1_weighted': 0.9329143568232805},
#  {'model': 'Unnamed',
#   'accuracy': 0.849910394265233,
#   'precision_w': 0.8586121973836254,
#   'recall_w': 0.849910394265233,
#   'precision_per_class': array([0.86477987, 0.90471204, 0.79040667]),
#   'recall_per_class': array([0.7994186 , 0.77978339, 0.97179487]),
#   'f1_macro': 0.846732071993289,
#   'f1_weighted': 0.8485014155288384},
#  {'model': 'Unnamed',
#   'accuracy': 0.9578713968957872,
#   'precision_w': 0.9586313185286043,
#   'recall_w': 0.9578713968957872,
#   'precision_per_class': array([0.90961171, 0.96928052, 0.96289569]),
#   'recall_per_class': array([0.99305073, 0.94390868, 0.9631456 ]),
#   'f1_macro': 0.9563162184236159,
#   'f1_weighted': 0.9579151386509149},
#  {'model': 'Unnamed',
#   'accuracy': 0.8812724014336918,
#   'precision_w': 0.8818701341541425,
#   'recall_w': 0.8812724014336918,
#   'precision_per_class': array([0.83852691, 0.898017  , 0.87804878]),
#   'recall_per_class': array([0.86046512, 0.85830325, 0.92307692]),
#   'f1_macro': 0.875688499087548,
#   'f1_weighted': 0.8811298511567789},
#  {'model': 'Unnamed',
#   'accuracy': 0.9652945146052251,
#   'precision_w': 0.9664406302063724,
#   'recall_w': 0.9652945146052251,
#   'precision_per_class': array([0.92516129, 0.98841299, 0.95288221]),
#   'recall_per_class': array([0.99652536, 0.94016926, 0.98676356]),
#   'f1_macro': 0.9642443048627293,
#   'f1_weighted': 0.965278262546766},
#  {'model': 'Unnamed',
#   'accuracy': 0.8736559139784946,
#   'precision_w': 0.8758530913179869,
#   'recall_w': 0.8736559139784946,
#   'precision_per_class': array([0.84090909, 0.90490196, 0.85      ]),
#   'recall_per_class': array([0.86046512, 0.83303249, 0.93717949]),
#   'f1_macro': 0.869839776761781,
#   'f1_weighted': 0.8732564236094937},
#  {'model': 'Unnamed',
#   'accuracy': 0.9652945146052251,
#   'precision_w': 0.9661211155248199,
#   'recall_w': 0.9652945146052251,
#   'precision_per_class': array([0.92884864, 0.98400656, 0.9564557 ]),
#   'recall_per_class': array([0.99791522, 0.94449911, 0.98053465]),
#   'f1_macro': 0.9647792413402727,
#   'f1_weighted': 0.9652822759607019},
#  {'model': 'Unnamed',
#   'accuracy': 0.8727598566308243,
#   'precision_w': 0.8743802805581977,
#   'recall_w': 0.8727598566308243,
#   'precision_per_class': array([0.84593023, 0.89922481, 0.85163551]),
#   'recall_per_class': array([0.84593023, 0.83754513, 0.93461538]),
#   'f1_macro': 0.868139332064696,
#   'f1_weighted': 0.8723528152658704},
#  {'model': 'Unnamed',
#   'accuracy': 0.9672225971271571,
#   'precision_w': 0.9675974182574375,
#   'recall_w': 0.9672225971271571,
#   'precision_per_class': array([0.94129288, 0.9791793 , 0.96214834]),
#   'recall_per_class': array([0.99166088, 0.95335564, 0.97638204]),
#   'f1_macro': 0.9670428367688967,
#   'f1_weighted': 0.9672150484181123},
#  {'model': 'Unnamed',
#   'accuracy': 0.8826164874551972,
#   'precision_w': 0.8829595910601048,
#   'recall_w': 0.8826164874551972,
#   'precision_per_class': array([0.85843373, 0.89681051, 0.87410072]),
#   'recall_per_class': array([0.82848837, 0.86281588, 0.93461538]),
#   'f1_macro': 0.8753419372621427,
#   'f1_weighted': 0.8822302949184109},
#  {'model': 'Unnamed',
#   'accuracy': 0.9653909187313217,
#   'precision_w': 0.9663052593842817,
#   'recall_w': 0.9653909187313217,
#   'precision_per_class': array([0.91528662, 0.98164015, 0.96513714]),
#   'recall_per_class': array([0.99861015, 0.94705767, 0.97716065]),
#   'f1_macro': 0.9634283821918891,
#   'f1_weighted': 0.9654307801059115},
#  {'model': 'Unnamed',
#   'accuracy': 0.8799283154121864,
#   'precision_w': 0.8811410113886402,
#   'recall_w': 0.8799283154121864,
#   'precision_per_class': array([0.84078212, 0.90307102, 0.86778846]),
#   'recall_per_class': array([0.875     , 0.84927798, 0.92564103]),
#   'f1_macro': 0.8762267774920939,
#   'f1_weighted': 0.8797461200915828},
#  {'model': 'Unnamed',
#   'accuracy': 0.9655837269835149,
#   'precision_w': 0.965682430573707,
#   'recall_w': 0.9655837269835149,
#   'precision_per_class': array([0.9497319 , 0.96661399, 0.9704111 ]),
#   'recall_per_class': array([0.98471161, 0.96299941, 0.96184791]),
#   'f1_macro': 0.9659397791463874,
#   'f1_weighted': 0.965580498886146},
#  {'model': 'Unnamed',
#   'accuracy': 0.8799283154121864,
#   'precision_w': 0.8797418686969879,
#   'recall_w': 0.8799283154121864,
#   'precision_per_class': array([0.86645963, 0.88043478, 0.88461538]),
#   'recall_per_class': array([0.81104651, 0.87725632, 0.91410256]),
#   'f1_macro': 0.8719325967717749,
#   'f1_weighted': 0.8796081438076497},
#  {'model': 'Unnamed',
#   'accuracy': 0.9649088981008387,
#   'precision_w': 0.9655765444274259,
#   'recall_w': 0.9649088981008387,
#   'precision_per_class': array([0.91869398, 0.96860719, 0.97908947]),
#   'recall_per_class': array([0.99722029, 0.9594568 , 0.96003114]),
#   'f1_macro': 0.9632749386696934,
#   'f1_weighted': 0.9649740529512227},
#  {'model': 'Unnamed',
#   'accuracy': 0.8884408602150538,
#   'precision_w': 0.8892504466299753,
#   'recall_w': 0.8884408602150538,
#   'precision_per_class': array([0.82608696, 0.90102708, 0.90037831]),
#   'recall_per_class': array([0.88372093, 0.87093863, 0.91538462]),
#   'f1_macro': 0.8824931451442005,
#   'f1_weighted': 0.8885474638904248},
#  {'model': 'Unnamed',
#   'accuracy': 0.9644268774703557,
#   'precision_w': 0.9649453770971406,
#   'recall_w': 0.9644268774703557,
#   'precision_per_class': array([0.96423562, 0.97886179, 0.9468587 ]),
#   'recall_per_class': array([0.95552467, 0.94784491, 0.98961848]),
#   'f1_macro': 0.9635768570123732,
#   'f1_weighted': 0.9643857374175019},
#  {'model': 'Unnamed',
#   'accuracy': 0.8754480286738351,
#   'precision_w': 0.8776337786012959,
#   'recall_w': 0.8754480286738351,
#   'precision_per_class': array([0.90333333, 0.89224953, 0.84553776]),
#   'recall_per_class': array([0.7877907 , 0.85198556, 0.9474359 ]),
#   'f1_macro': 0.8689530056388614,
#   'f1_weighted': 0.8746899899401579},
#  {'model': 'Unnamed',
#   'accuracy': 0.9651981104791285,
#   'precision_w': 0.965939193759392,
#   'recall_w': 0.9651981104791285,
#   'precision_per_class': array([0.9157626 , 0.97599839, 0.97141372]),
#   'recall_per_class': array([0.99722029, 0.95237158, 0.97015313]),
#   'f1_macro': 0.9631934702022905,
#   'f1_weighted': 0.9652570109644771},
#  {'model': 'Unnamed',
#   'accuracy': 0.8835125448028673,
#   'precision_w': 0.8847035015758093,
#   'recall_w': 0.8835125448028673,
#   'precision_per_class': array([0.82465753, 0.90535373, 0.8818514 ]),
#   'recall_per_class': array([0.875     , 0.85469314, 0.92820513]),
#   'f1_macro': 0.8776040934035204,
#   'f1_weighted': 0.883423762869074},
#  {'model': 'Unnamed',
#   'accuracy': 0.9656801311096115,
#   'precision_w': 0.9664768489314673,
#   'recall_w': 0.9656801311096115,
#   'precision_per_class': array([0.94849498, 0.98581123, 0.94769614]),
#   'recall_per_class': array([0.98540653, 0.94351506, 0.98754217]),
#   'f1_macro': 0.966002321757896,
#   'f1_weighted': 0.9656501556557697},
#  {'model': 'Unnamed',
#   'accuracy': 0.8790322580645161,
#   'precision_w': 0.8806276839742265,
#   'recall_w': 0.8790322580645161,
#   'precision_per_class': array([0.87009063, 0.90288462, 0.85365854]),
#   'recall_per_class': array([0.8372093 , 0.84747292, 0.94230769]),
#   'f1_macro': 0.8744767520372395,
#   'f1_weighted': 0.8785811900333681},
#  {'model': 'Unnamed',
#   'accuracy': 0.9683794466403162,
#   'precision_w': 0.9686946707404481,
#   'recall_w': 0.9683794466403162,
#   'precision_per_class': array([0.93774574, 0.97050089, 0.97787144]),
#   'recall_per_class': array([0.99444058, 0.96477071, 0.96340514]),
#   'f1_macro': 0.9678243640999368,
#   'f1_weighted': 0.9683974929873043},
#  {'model': 'Unnamed',
#   'accuracy': 0.882168458781362,
#   'precision_w': 0.882028777987114,
#   'recall_w': 0.882168458781362,
#   'precision_per_class': array([0.84365782, 0.8872594 , 0.8915212 ]),
#   'recall_per_class': array([0.83139535, 0.87364621, 0.91666667]),
#   'f1_macro': 0.8739336566833732,
#   'f1_weighted': 0.8820044784071566},
#  {'model': 'Unnamed',
#   'accuracy': 0.9702111250361516,
#   'precision_w': 0.9704983684580482,
#   'recall_w': 0.9702111250361516,
#   'precision_per_class': array([0.94013158, 0.9770092 , 0.9732537 ]),
#   'recall_per_class': array([0.99305073, 0.96181854, 0.97274851]),
#   'f1_macro': 0.9694074147170392,
#   'f1_weighted': 0.9702250931179137},
#  {'model': 'Unnamed',
#   'accuracy': 0.8870967741935484,
#   'precision_w': 0.8872280535044252,
#   'recall_w': 0.8870967741935484,
#   'precision_per_class': array([0.86297376, 0.8962963 , 0.88504326]),
#   'recall_per_class': array([0.86046512, 0.87364621, 0.91794872]),
#   'f1_macro': 0.8825798862665436,
#   'f1_weighted': 0.8869852551136954},
#  {'model': 'Unnamed',
#   'accuracy': 0.9600886917960089,
#   'precision_w': 0.9615001897786265,
#   'recall_w': 0.9600886917960089,
#   'precision_per_class': array([0.88985149, 0.97208173, 0.97430519]),
#   'recall_per_class': array([0.99930507, 0.94567998, 0.96444329]),
#   'f1_macro': 0.9564852698269145,
#   'f1_weighted': 0.960256240406428},
#  {'model': 'Unnamed',
#   'accuracy': 0.8884408602150538,
#   'precision_w': 0.8893286779265615,
#   'recall_w': 0.8884408602150538,
#   'precision_per_class': array([0.82513661, 0.90480679, 0.89565217]),
#   'recall_per_class': array([0.87790698, 0.86642599, 0.92435897]),
#   'f1_macro': 0.8818946528043946,
#   'f1_weighted': 0.8884732198812166},
#  {'model': 'Unnamed',
#   'accuracy': 0.9682830425142196,
#   'precision_w': 0.9691582471698341,
#   'recall_w': 0.9682830425142196,
#   'precision_per_class': array([0.92002559, 0.98489796, 0.96675192]),
#   'recall_per_class': array([0.99930507, 0.94981303, 0.98105372]),
#   'f1_macro': 0.9663052226501061,
#   'f1_weighted': 0.9683181734539589},
#  {'model': 'Unnamed',
#   'accuracy': 0.8772401433691757,
#   'precision_w': 0.8783679802230602,
#   'recall_w': 0.8772401433691757,
#   'precision_per_class': array([0.83098592, 0.90019194, 0.86826347]),
#   'recall_per_class': array([0.85755814, 0.8465704 , 0.92948718]),
#   'f1_macro': 0.871484634646528,
#   'f1_weighted': 0.8769989560569},
#  {'model': 'Unnamed',
#   'accuracy': 0.9528583823387641,
#   'precision_w': 0.9543409651951519,
#   'recall_w': 0.9528583823387641,
#   'precision_per_class': array([0.91848524, 0.93917368, 0.98773348]),
#   'recall_per_class': array([0.99444058, 0.96634521, 0.91954321]),
#   'f1_macro': 0.9533133430226949,
#   'f1_weighted': 0.95284280092616},
#  {'model': 'Unnamed',
#   'accuracy': 0.891500904159132,
#   'precision_w': 0.8918543312015097,
#   'recall_w': 0.891500904159132,
#   'precision_per_class': array([0.85139319, 0.88018018, 0.92426187]),
#   'recall_per_class': array([0.83841463, 0.90129151, 0.9       ]),
#   'f1_macro': 0.8824781427609185,
#   'f1_weighted': 0.8915505769219597},
#  {'model': 'Unnamed',
#   'accuracy': 0.9528583823387641,
#   'precision_w': 0.9543409651951519,
#   'recall_w': 0.9528583823387641,
#   'precision_per_class': array([0.91848524, 0.93917368, 0.98773348]),
#   'recall_per_class': array([0.99444058, 0.96634521, 0.91954321]),
#   'f1_macro': 0.9533133430226949,
#   'f1_weighted': 0.95284280092616},
#  {'model': 'Unnamed',
#   'accuracy': 0.889336917562724,
#   'precision_w': 0.8905386401299357,
#   'recall_w': 0.889336917562724,
#   'precision_per_class': array([0.83008357, 0.8806366 , 0.93126685]),
#   'recall_per_class': array([0.86627907, 0.89891697, 0.88589744]),
#   'f1_macro': 0.8818312754863907,
#   'f1_weighted': 0.8896337287617302},
#  {'model': 'Unnamed',
#   'accuracy': 0.891500904159132,
#   'precision_w': 0.8918543312015097,
#   'recall_w': 0.891500904159132,
#   'precision_per_class': array([0.85139319, 0.88018018, 0.92426187]),
#   'recall_per_class': array([0.83841463, 0.90129151, 0.9       ]),
#   'f1_macro': 0.8824781427609185,
#   'f1_weighted': 0.8915505769219597}]

# %%
learning_train_data = [learning_data[i] for i in range(0, len(learning_data), 2)]
learning_test_data = [learning_data[i] for i in range(1, len(learning_data), 2)]
import json

with open(PROJECT_ROOT / "outputs/learning_data/lstm_attention_train1.json", "w") as f:
    json.dump(serialize(learning_train_data), f, indent=4)

with open(PROJECT_ROOT / "outputs/learning_data/lstm_attention_test1.json", "w") as f:
    json.dump(serialize(learning_test_data), f, indent=4)

# %%
from torchinfo import summary

example_input = {
    **x_test
}

summary(model, input_data=example_input, depth=4)
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# OptimizedGradePredictionModel                      [2212, 3]                 --
# ├─Embedding: 1-1                                   [2212, 7]                 406
# ├─Embedding: 1-2                                   [2212, 22]                11,044
# ├─Embedding: 1-3                                   [2212, 21]                9,303
# ├─Embedding: 1-4                                   [2212, 8]                 584
# ├─Embedding: 1-5                                   [2212, 4, 10, 7]          (recursive)
# ├─Embedding: 1-6                                   [2212, 4, 10, 22]         (recursive)
# ├─Embedding: 1-7                                   [2212, 4, 10, 21]         (recursive)
# ├─Embedding: 1-8                                   [2212, 4, 10, 8]          (recursive)
# ├─OptimizedConditionalAttentionPooling: 1-9        [2212, 4, 64]             --
# │    └─Linear: 2-1                                 [2212, 64]                6,272
# │    └─Linear: 2-2                                 [2212, 4, 10, 64]         6,336
# │    └─Linear: 2-3                                 [2212, 4, 10, 64]         6,336
# ├─LSTM: 1-10                                       [2212, 4, 64]             66,560
# ├─Sequential: 1-11                                 [2212, 3]                 --
# │    └─Linear: 2-4                                 [2212, 64]                10,432
# │    └─ReLU: 2-5                                   [2212, 64]                --
# │    └─Dropout: 2-6                                [2212, 64]                --
# │    └─Linear: 2-7                                 [2212, 32]                2,080
# │    └─ReLU: 2-8                                   [2212, 32]                --
# │    └─Linear: 2-9                                 [2212, 3]                 99
# ====================================================================================================
# Total params: 119,452
# Trainable params: 119,452
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 753.12
# ====================================================================================================
# Input size (MB): 17.94
# Forward/backward pass size (MB): 140.10
# Params size (MB): 0.48
# Estimated Total Size (MB): 158.51
# ====================================================================================================

# %%
model.eval()
with torch.no_grad():
    print("Best Train:")
    train_preds = best_model(**train_dataset.x_gpu).argmax(dim=1).cpu().numpy()
    train_true = train_dataset.y_cpu.numpy()
    evaluate_model(train_true, train_preds, learning_data)
    print("Best Val:")
    evaluate_model(y_val, model(**x_val).argmax(dim=1).cpu().numpy(), learning_data)
    print("Best Test:")
    evaluate_model(y_test, model(**x_test).argmax(dim=1).cpu().numpy(), learning_data)
# Out:
# Best Train:
# C:\Python\projects\CGPAPrediction\.venv\Lib\site-packages\torch\nn\modules\rnn.py:1123: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\cudnn\RNN.cpp:1410.)
#   result = _VF.lstm(
#   Metrics:
#   Accuracy:       0.9529
#   Precision (w):  0.9543
#   Recall (w):     0.9529
#   Precision (per class):  ['0.9185', '0.9392', '0.9877']
#   Recall (per class):  ['0.9944', '0.9663', '0.9195']
#   F1 (macro):     0.9533
#   F1 (weighted):  0.9528
#
# Confusion Matrix:
#       0     1     2
# 0  1431     8     0
# 1   127  4910    44
# 2     0   310  3543
# Best Val:
#   Metrics:
#   Accuracy:       0.8893
#   Precision (w):  0.8905
#   Recall (w):     0.8893
#   Precision (per class):  ['0.8301', '0.8806', '0.9313']
#   Recall (per class):  ['0.8663', '0.8989', '0.8859']
#   F1 (macro):     0.8818
#   F1 (weighted):  0.8896
#
# Confusion Matrix:
#      0    1    2
# 0  298   46    0
# 1   61  996   51
# 2    0   89  691
# Best Test:
#   Metrics:
#   Accuracy:       0.8915
#   Precision (w):  0.8919
#   Recall (w):     0.8915
#   Precision (per class):  ['0.8514', '0.8802', '0.9243']
#   Recall (per class):  ['0.8384', '0.9013', '0.9000']
#   F1 (macro):     0.8825
#   F1 (weighted):  0.8916
#
# Confusion Matrix:
#      0    1    2
# 0  275   53    0
# 1   48  977   59
# 2    0   80  720

# %%
for k, v in train_dataset.x_cpu['other_semesters'].items():
    print(f'{k} - {v.shape}')
# Out:
# educational_program - torch.Size([10373, 4, 10])
# course - torch.Size([10373, 4, 10])
# instructor_name - torch.Size([10373, 4, 10])
# instructor_department - torch.Size([10373, 4, 10])
# tensor_features - torch.Size([10373, 4, 10, 41])
# mask - torch.Size([10373, 4, 10])
